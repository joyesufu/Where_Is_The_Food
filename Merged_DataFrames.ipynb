# %% [markdown]
# # This is where the merged dataframe is created and cleaned

# %%
# Import dependencies
from pprint import pprint
import pandas as pd 
import requests
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets

#yelp_api_key =

# %%
#import the API data
yelp_csv = pd.read_csv('yelp_csv/yelp_csv_CLEAN2.csv', dtype=object)
yelp_csv.head(5)
# Out:
#   Unnamed: 0             name     category  category_title rating price  \
# 0          0  Tortas Frontera      mexican         Mexican      4    $$
# 1          1  Farmer's Fridge        salad           Salad    4.5     $
# 2          2  Tortas Frontera      mexican         Mexican      4    $$
# 3          3    Gaslight Club  newamerican  American (New)    3.5   $$$
# 4          4         Big Bowl      chinese         Chinese      2    $$
#
#   review_count                                    display_address  \
# 0         1395  ['Terminal 3 - Gate K4', "10000 W O'Hare ", 'T...
# 1           62  ['10000 Ohare Way', 'Terminal 3 Gate K6', 'Chi...
# 2         1321  ["10000 W O'Hare ", 'Terminal 1 - Gate B11', '...
# 3           99  ["Chicago O'Hare International Airport", "O'Ha...
# 4           36  ["10000 West O'hare ", 'Terminal 5; Gate M7', ...
#
#                                address1         address2  \
# 0                  Terminal 3 - Gate K4  10000 W O'Hare
# 1                       10000 Ohare Way              NaN
# 2                       10000 W O'Hare               NaN
# 3  Chicago O'Hare International Airport              NaN
# 4                    10000 West O'hare               NaN
#
#                             address3     city     latitude     longitude  \
# 0     Terminal 3 Concourse K Gate K4  Chicago    41.975438    -87.900137
# 1                 Terminal 3 Gate K6  Chicago  41.97523427  -87.89871916
# 2              Terminal 1 - Gate B11  Chicago  41.98002633  -87.90667938
# 3  O'Hare Hilton Hotel - Lobby Level  Chicago  41.97796482   -87.9051733
# 4                Terminal 5; Gate M7  Chicago  41.97510276  -87.89135034
#
#   zip code           restaurant_id price_integer
# 0    60666  1zZvM7Zy__Oh533E4bt6_A             2
# 1    60666  4xQv1b1IFRsAWZu7yVLFrQ             1
# 2    60666  0k018u1PAtfmkNRYk04yCQ             2
# 3    60666  MywzBEKWjmt0bcNajKt8yw             3
# 4    60666  6VZwwWxBmxMsKd10AIOjxg             2

# %%
#import the API data
inspection = pd.read_csv('Inspection_Data/Inspection_Data_Clean2.csv', dtype=object)
inspection.head(5)
# Out:
#              Address         Address_old            AKA Name Facility Type  \
# 0     1950 W Polk St     1950 W Polk St            RED MANGO    Restaurant
# 1  4412 N Pulaski Rd  4412 N Pulaski Rd              WENDY'S    Restaurant
# 2     1401 W 18th St     1401 W 18th St     GIORDANO'S PIZZA    Restaurant
# 3   5420 W Fullerton  5420 W Fullerton    ALEX LA MICHOACANA    Restaurant
# 4    2167 S China Pl    2167 S China Pl           KYO MATCHA    Restaurant
#
#               Risk    Zip  Year          Inspection Type Results  \
# 0  Risk 2 (Medium)  60612  2022                  License    Pass
# 1    Risk 1 (High)  60630  2022  Complaint Re-Inspection    Pass
# 2    Risk 1 (High)  60608  2022                  Canvass    Pass
# 3    Risk 1 (High)  60639  2022    Canvass Re-Inspection    Pass
# 4  Risk 2 (Medium)  60616  2022                  License    Pass
#
#                                           Violations     Latitude  \
# 0                                                NaN  41.87159625
# 1                                                NaN  41.96136649
# 2  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.85776469
# 3                                                NaN   41.9241413
# 4                                                NaN  41.85355612
#
#       Longitude
# 0  -87.67582148
# 1  -87.72798668
# 2  -87.66138509
# 3  -87.76192142
# 4  -87.63519795

# %%
inspection.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
inspection = inspection.rename(columns={'Address': 'address1', 'Zip': 'zip code'})

# %%
#eventually to merge
Merged = pd.merge(yelp_csv, inspection, how="right", on=['address1'])
Merged
# Out:
#      Unnamed: 0                        name category category_title rating  \
# 0           NaN                         NaN      NaN            NaN    NaN
# 1          3560                     Wendy's  hotdogs      Fast Food    1.5
# 2          4779                  Giordano's    salad          Salad    2.5
# 3           NaN                         NaN      NaN            NaN    NaN
# 4           NaN                         NaN      NaN            NaN    NaN
# ...         ...                         ...      ...            ...    ...
# 2059       4774  Fiesta Tamaleria El Barrio  mexican        Mexican    4.5
# 2060        NaN                         NaN      NaN            NaN    NaN
# 2061        NaN                         NaN      NaN            NaN    NaN
# 2062        NaN                         NaN      NaN            NaN    NaN
# 2063        NaN                         NaN      NaN            NaN    NaN
#
#      price review_count                             display_address  \
# 0      NaN          NaN                                         NaN
# 1        $           66  ['4412 N Pulaski Rd', 'Chicago, IL 60630']
# 2       $$           68     ['1401 W 18th St', 'Chicago, IL 60608']
# 3      NaN          NaN                                         NaN
# 4      NaN          NaN                                         NaN
# ...    ...          ...                                         ...
# 2059   NaN           12     ['1820 W 18th St', 'Chicago, IL 60608']
# 2060   NaN          NaN                                         NaN
# 2061   NaN          NaN                                         NaN
# 2062   NaN          NaN                                         NaN
# 2063   NaN          NaN                                         NaN
#
#                    address1 address2  ...                    AKA Name  \
# 0            1950 W Polk St      NaN  ...                   RED MANGO
# 1         4412 N Pulaski Rd      NaN  ...                     WENDY'S
# 2            1401 W 18th St      NaN  ...            GIORDANO'S PIZZA
# 3          5420 W Fullerton      NaN  ...          ALEX LA MICHOACANA
# 4           2167 S China Pl      NaN  ...                  KYO MATCHA
# ...                     ...      ...  ...                         ...
# 2059         1820 W 18th St      NaN  ...  FIESTA TAMALERIA EL BARRIO
# 2060  4212-4214 N Milwaukee      NaN  ...         LA PENA RESTAURANTE
# 2061       1139 W Bryn Mawr      NaN  ...        BEN'S NOODLES & RICE
# 2062    8645 S Stony Island      NaN  ...                     WENDY'S
# 2063    2351 W Augusta Blvd      NaN  ...   JOEY'S G'S MAC AND CHEESE
#
#      Facility Type             Risk zip code_y  Year          Inspection Type  \
# 0       Restaurant  Risk 2 (Medium)      60612  2022                  License
# 1       Restaurant    Risk 1 (High)      60630  2022  Complaint Re-Inspection
# 2       Restaurant    Risk 1 (High)      60608  2022                  Canvass
# 3       Restaurant    Risk 1 (High)      60639  2022    Canvass Re-Inspection
# 4       Restaurant  Risk 2 (Medium)      60616  2022                  License
# ...            ...              ...        ...   ...                      ...
# 2059    Restaurant  Risk 2 (Medium)      60608  2022                  License
# 2060    Restaurant    Risk 1 (High)      60641  2022                  Canvass
# 2061    Restaurant    Risk 1 (High)      60660  2022    Canvass Re-Inspection
# 2062    Restaurant    Risk 1 (High)      60617  2022  Complaint Re-Inspection
# 2063    Restaurant    Risk 1 (High)      60622  2022                  Canvass
#
#      Results                                         Violations     Latitude  \
# 0       Pass                                                NaN  41.87159625
# 1       Pass                                                NaN  41.96136649
# 2       Pass  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.85776469
# 3       Pass                                                NaN   41.9241413
# 4       Pass                                                NaN  41.85355612
# ...      ...                                                ...          ...
# 2059    Pass                                                NaN  41.85782113
# 2060    Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...   41.9573322
# 2061    Pass  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.98351971
# 2062    Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.73740694
# 2063    Pass  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.89927625
#
#          Longitude
# 0     -87.67582148
# 1     -87.72798668
# 2     -87.66138509
# 3     -87.76192142
# 4     -87.63519795
# ...            ...
# 2059  -87.67198407
# 2060  -87.75179742
# 2061  -87.65963856
# 2062  -87.58506914
# 2063  -87.68650717
#
# [2064 rows x 28 columns]

# %%
Merged.to_csv('Merged.csv', index=False)

# %%
Merged['name'].replace('', np.nan, inplace=True)
Merged.dropna(subset=['name'], inplace=True)

# %%
Merged
# Out:
#      Unnamed: 0                         name     category  \
# 1          3560                      Wendy's      hotdogs
# 2          4779                   Giordano's        salad
# 5          5719       Potbelly Sandwich Shop   sandwiches
# 6          5502                    Amazon Go  convenience
# 7          5975  Wildberry Pancakes and Cafe     pancakes
# ...         ...                          ...          ...
# 2049       4724                       Pi18en   newmexican
# 2050       6277                       Pl-zen   gastropubs
# 2053       3574                   McDonald's      hotdogs
# 2058       4591  Fiesta Tamaleria Del Barrio      mexican
# 2059       4774   Fiesta Tamaleria El Barrio      mexican
#
#            category_title rating price review_count  \
# 1               Fast Food    1.5     $           66
# 2                   Salad    2.5    $$           68
# 5              Sandwiches      3     $           30
# 6      Convenience Stores    3.5   NaN            4
# 7                Pancakes    4.5    $$         8246
# ...                   ...    ...   ...          ...
# 2049  New Mexican Cuisine    3.5   NaN            3
# 2050           Gastropubs      4    $$          389
# 2053            Fast Food    2.5     $           30
# 2058              Mexican      5   NaN            3
# 2059              Mexican    4.5   NaN           12
#
#                                      display_address               address1  \
# 1         ['4412 N Pulaski Rd', 'Chicago, IL 60630']      4412 N Pulaski Rd
# 2            ['1401 W 18th St', 'Chicago, IL 60608']         1401 W 18th St
# 5           ['1 N La Salle St', 'Chicago, IL 60602']        1 N La Salle St
# 6         ['130 E Randolph St', 'Chicago, IL 60601']      130 E Randolph St
# 7         ['130 E Randolph St', 'Chicago, IL 60601']      130 E Randolph St
# ...                                              ...                    ...
# 2049         ['1519 W 18th St', 'Chicago, IL 60608']         1519 W 18th St
# 2050         ['1519 W 18th St', 'Chicago, IL 60608']         1519 W 18th St
# 2053  ['3615 W Irving Park Rd', 'Chicago, IL 60618']  3615 W Irving Park Rd
# 2058         ['1820 W 18th St', 'Chicago, IL 60608']         1820 W 18th St
# 2059         ['1820 W 18th St', 'Chicago, IL 60608']         1820 W 18th St
#
#      address2  ...                     AKA Name Facility Type  \
# 1         NaN  ...                      WENDY'S    Restaurant
# 2         NaN  ...             GIORDANO'S PIZZA    Restaurant
# 5         NaN  ...  POTBELLY SANDWICH WORKS LLC    Restaurant
# 6         NaN  ...                   GIORDANO'S    Restaurant
# 7         NaN  ...                   GIORDANO'S    Restaurant
# ...       ...  ...                          ...           ...
# 2049      NaN  ...                       PI18EN    Restaurant
# 2050      NaN  ...                       PI18EN    Restaurant
# 2053      NaN  ...                    MCDONALDS    Restaurant
# 2058      NaN  ...   FIESTA TAMALERIA EL BARRIO    Restaurant
# 2059      NaN  ...   FIESTA TAMALERIA EL BARRIO    Restaurant
#
#                  Risk zip code_y  Year          Inspection Type Results  \
# 1       Risk 1 (High)      60630  2022  Complaint Re-Inspection    Pass
# 2       Risk 1 (High)      60608  2022                  Canvass    Pass
# 5       Risk 1 (High)      60602  2022                  Canvass    Fail
# 6       Risk 1 (High)      60601  2022                  License    Pass
# 7       Risk 1 (High)      60601  2022                  License    Pass
# ...               ...        ...   ...                      ...     ...
# 2049    Risk 1 (High)      60608  2022                  Canvass    Fail
# 2050    Risk 1 (High)      60608  2022                  Canvass    Fail
# 2053  Risk 2 (Medium)      60618  2022                  Canvass    Pass
# 2058  Risk 2 (Medium)      60608  2022                  License    Pass
# 2059  Risk 2 (Medium)      60608  2022                  License    Pass
#
#                                              Violations     Latitude  \
# 1                                                   NaN  41.96136649
# 2     55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.85776469
# 5     38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.88199007
# 6     38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.88458837
# 7     38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.88458837
# ...                                                 ...          ...
# 2049  22. PROPER COLD HOLDING TEMPERATURES - Comment...  41.85771387
# 2050  22. PROPER COLD HOLDING TEMPERATURES - Comment...  41.85771387
# 2053  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.95364665
# 2058                                                NaN  41.85782113
# 2059                                                NaN  41.85782113
#
#          Longitude
# 1     -87.72798668
# 2     -87.66138509
# 5     -87.63221288
# 6     -87.62327256
# 7     -87.62327256
# ...            ...
# 2049  -87.66454238
# 2050  -87.66454238
# 2053  -87.71848491
# 2058  -87.67198407
# 2059  -87.67198407
#
# [965 rows x 28 columns]

# %%
Merged.to_csv('Merged_Clean.csv', index=False)
