# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from citipy import citipy
from config import yelp_key
from config import g_key
# from config import client_key

# %%
#pull in Yelp API data

url = "https://api.yelp.com/v3/businesses/search?"
headers = {"Authorization": "Bearer {}".format(yelp_key)}
params = {"location": "Chicago",
         "limit": 50,}
city = "Chicago"

#potential parameters are location, price, rating

response = requests.get(url, headers=headers, params=params)
chicago_data = response.json()
chicago_data
# Out:
# {'businesses': [{'id': 'qjnpkS8yZO8xcyEIy5OU9A',
#    'alias': 'girl-and-the-goat-chicago',
#    'name': 'Girl & The Goat',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ya6gjD4BPlxe7AKMj_5WsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/girl-and-the-goat-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 9048,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.88418277967144,
#     'longitude': -87.64797390222085},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '809 W Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['809 W Randolph St', 'Chicago, IL 60607']},
#    'phone': '+13124926262',
#    'display_phone': '(312) 492-6262',
#    'distance': 3394.213019789188},
#   {'id': 'cKZNbMvoqJaUe7n6lf6i7w',
#    'alias': 'wildberry-pancakes-and-cafe-chicago-2',
#    'name': 'Wildberry Pancakes and Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/43XNyVUbPJNtC6IFobGRMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wildberry-pancakes-and-cafe-chicago-2?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 8241,
#    'categories': [{'alias': 'pancakes', 'title': 'Pancakes'},
#     {'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.884668, 'longitude': -87.62288},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '130 E Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60601',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['130 E Randolph St', 'Chicago, IL 60601']},
#    'phone': '+13129389777',
#    'display_phone': '(312) 938-9777',
#    'distance': 5082.221755403031},
#   {'id': 'xoi7Cw7FoknAx5p880RtWQ',
#    'alias': 'au-cheval-chicago',
#    'name': 'Au Cheval',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/a0yhvSJX_6i28iwS9egDFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/au-cheval-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 7632,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.88466, 'longitude': -87.647668},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '800 W Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['800 W Randolph St', 'Chicago, IL 60607']},
#    'phone': '+13129294580',
#    'display_phone': '(312) 929-4580',
#    'distance': 3376.5984269738638},
#   {'id': 'boE4Ahsssqic7o5wQLI04w',
#    'alias': 'the-purple-pig-chicago',
#    'name': 'The Purple Pig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oBPWSL6uQnJ9mAfWM2yxKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-purple-pig-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 7537,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.890694, 'longitude': -87.624782},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '444 N Michigan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['444 N Michigan Ave', 'Chicago, IL 60611']},
#    'phone': '+13124641744',
#    'display_phone': '(312) 464-1744',
#    'distance': 4670.876906589787},
#   {'id': '8vFJH_paXsMocmEO_KAa3w',
#    'alias': 'lou-malnatis-pizzeria-chicago',
#    'name': "Lou Malnati's Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9FiL-9Pbytyg6usOE02lYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 6495,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.890357, 'longitude': -87.633704},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '439 N Wells St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['439 N Wells St', 'Chicago, IL 60654']},
#    'phone': '+13128289800',
#    'display_phone': '(312) 828-9800',
#    'distance': 4000.9990531720227},
#   {'id': 'AkcZ1fUyB3RocKLYGFu20Q',
#    'alias': 'art-institute-of-chicago-chicago-3',
#    'name': 'Art Institute of Chicago',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LGtQrnCRJCBNsAS1-x2ilQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/art-institute-of-chicago-chicago-3?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1982,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8796, 'longitude': -87.623713},
#    'transactions': [],
#    'location': {'address1': '111 S Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60603',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['111 S Michigan Ave', 'Chicago, IL 60603']},
#    'phone': '+13124433600',
#    'display_phone': '(312) 443-3600',
#    'distance': 5300.4255940425155},
#   {'id': 'apyIymDFbUK7u-Y3V5kmkA',
#    'alias': 'bavettes-bar-and-boeuf-chicago',
#    'name': "Bavette's Bar & Boeuf",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S3JMuUApnneZrpoQPz_KFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bavettes-bar-and-boeuf-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2609,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8892796234574,
#     'longitude': -87.6348227262497},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '218 W Kinzie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['218 W Kinzie St', 'Chicago, IL 60654']},
#    'phone': '+13126248154',
#    'display_phone': '(312) 624-8154',
#    'distance': 3968.647508362347},
#   {'id': 'y8jVBaHh8ntYkVqDXpsi1Q',
#    'alias': 'cafe-ba-ba-reeba-chicago-3',
#    'name': 'Cafe Ba-Ba-Reeba!',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AcR0FyQXw3q5JDsYLT4JMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-ba-ba-reeba-chicago-3?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 4389,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.918984, 'longitude': -87.648687},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2024 N Halsted St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2024 N Halsted St', 'Chicago, IL 60614']},
#    'phone': '+17739355000',
#    'display_phone': '(773) 935-5000',
#    'distance': 2855.2746085318017},
#   {'id': 'LPwAwxEjetjdNh7Uadro3g',
#    'alias': 'smoque-bbq-chicago',
#    'name': 'Smoque BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wBfhSd0v-aCmJmXgf26f-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smoque-bbq-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 4389,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.95021, 'longitude': -87.72795},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3800 N Pulaski Rd',
#     'address2': 'Ste 2',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60641',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3800 N Pulaski Rd', 'Ste 2', 'Chicago, IL 60641']},
#    'phone': '+17735457427',
#    'display_phone': '(773) 545-7427',
#    'distance': 6500.5755866125955},
#   {'id': '-sdMTRmgExufOk6STZFi9w',
#    'alias': 'little-goat-diner-chicago-5',
#    'name': 'Little Goat Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FEdL5JcbVf5NFEB3s5S8Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-goat-diner-chicago-5?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 4755,
#    'categories': [{'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8846460590586,
#     'longitude': -87.6484126982138},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '820 W Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['820 W Randolph St', 'Chicago, IL 60607']},
#    'phone': '+13128883455',
#    'display_phone': '(312) 888-3455',
#    'distance': 3332.4445948347225},
#   {'id': 'DXwSYgiXqIVNdO9dazel6w',
#    'alias': 'pequods-pizzeria-chicago',
#    'name': "Pequod's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8QJUNblfCI0EDhOjuIWJ4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pequods-pizzeria-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 6788,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92187, 'longitude': -87.664486},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2207 N Clybourn Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2207 N Clybourn Ave', 'Chicago, IL 60614']},
#    'phone': '+17733271512',
#    'display_phone': '(773) 327-1512',
#    'distance': 2158.7084581522413},
#   {'id': 'ziIfrqtyupmeNlPAOx6jTw',
#    'alias': 'quartino-ristorante-chicago',
#    'name': 'Quartino Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z6YpgycrUniinFNWWMzzDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quartino-ristorante-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 4967,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8934479679332,
#     'longitude': -87.6283662020996},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '626 N State St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['626 N State St', 'Chicago, IL 60654']},
#    'phone': '+13126985000',
#    'display_phone': '(312) 698-5000',
#    'distance': 4290.83829114424},
#   {'id': 'pbEiXam9YJL3neCYHGwLUA',
#    'alias': 'alinea-chicago',
#    'name': 'Alinea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MEQO5WCbl9p-v2WjqrYmiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alinea-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2386,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9134194160823,
#     'longitude': -87.6482384681229},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '1723 N Halsted St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1723 N Halsted St', 'Chicago, IL 60614']},
#    'phone': '+13128670110',
#    'display_phone': '(312) 867-0110',
#    'distance': 2610.289488504425},
#   {'id': 'pVPyt3TugMd8FW5LGznkQQ',
#    'alias': 'kumas-corner-belmont-chicago',
#    'name': "Kuma's Corner - Belmont",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z3o3Cx-kEHX67fmqa_Bnqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kumas-corner-belmont-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 5159,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.939640045166,
#     'longitude': -87.7004470825195},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2900 W Belmont Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60618',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2900 W Belmont Ave', 'Chicago, IL 60618']},
#    'phone': '+17736048769',
#    'display_phone': '(773) 604-8769',
#    'distance': 4259.267413825311},
#   {'id': '2tKMs0DbdxPSl2JeCJUEKw',
#    'alias': 'joes-seafood-prime-steak-and-stone-crab-chicago',
#    'name': "Joe's Seafood, Prime Steak & Stone Crab",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qdKlgUn4qNIEPykt4lF-dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-seafood-prime-steak-and-stone-crab-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2656,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.891938, 'longitude': -87.62569},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '60 E Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['60 E Grand Ave', 'Chicago, IL 60611']},
#    'phone': '+13123795637',
#    'display_phone': '(312) 379-5637',
#    'distance': 4561.992190086001},
#   {'id': 'WBU0yq9J8qiYQfI_fh2P1Q',
#    'alias': 'crisp-chicago',
#    'name': 'Crisp',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CnRIO7IzEAAZ6rGu0kAPtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crisp-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3350,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9361214592879,
#     'longitude': -87.6444210345452},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2940 N Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2940 N Broadway Ave', 'Chicago, IL 60657']},
#    'phone': '+17736977610',
#    'display_phone': '(773) 697-7610',
#    'distance': 4411.791307760452},
#   {'id': 'rp17Dfjdh7JR4GGZwj6nqg',
#    'alias': 'portillos-hot-dogs-chicago-4',
#    'name': "Portillo's Hot Dogs",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-9jRmNrw7QgjcUn_EXVsEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portillos-hot-dogs-chicago-4?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 5999,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.89366, 'longitude': -87.63157},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '100 W Ontario',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['100 W Ontario', 'Chicago, IL 60654']},
#    'phone': '+13125878910',
#    'display_phone': '(312) 587-8910',
#    'distance': 4040.796149927089},
#   {'id': 'LYppbvgJlBG0SqjSKFiFGg',
#    'alias': 'sapori-trattoria-chicago',
#    'name': 'Sapori Trattoria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AicJhqa0W6ZPgP41Rz6WNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapori-trattoria-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2482,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.93165443680187,
#     'longitude': -87.64880961567327},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2701 N Halsted St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2701 N Halsted St', 'Chicago, IL 60614']},
#    'phone': '+17738329999',
#    'display_phone': '(773) 832-9999',
#    'distance': 3797.2733553838348},
#   {'id': 'jGiKIJCVLZHXQDSNnSLPsw',
#    'alias': 'xoco-chicago',
#    'name': 'Xoco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Z6QVmxTHd16d28e_5eEdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xoco-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3738,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.890969, 'longitude': -87.630776},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '449 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['449 N Clark St', 'Chicago, IL 60654']},
#    'phone': '+13127232131',
#    'display_phone': '(312) 723-2131',
#    'distance': 4196.9880258606},
#   {'id': 'ULEy88tbRkbwnDOOBdUCUQ',
#    'alias': 'mollys-cupcakes-chicago',
#    'name': "Molly's Cupcakes",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gWYFOtFpHSXuof03Cp0XLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mollys-cupcakes-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2865,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9288051, 'longitude': -87.6425736},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2536 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2536 N Clark St', 'Chicago, IL 60614']},
#    'phone': '+17738837220',
#    'display_phone': '(773) 883-7220',
#    'distance': 3918.592204438793},
#   {'id': 'vvhfPV-Llkd4fE2SHuLVvA',
#    'alias': 'the-gage-chicago',
#    'name': 'The Gage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w_OsQdxroFfNbT3N-xMFgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gage-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3071,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.881369, 'longitude': -87.624698},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '24 S Michigan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60603',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['24 S Michigan Ave', 'Chicago, IL 60603']},
#    'phone': '+13123724243',
#    'display_phone': '(312) 372-4243',
#    'distance': 5127.540787781295},
#   {'id': '2DfcXGtDv7T_rnvl4lHzaQ',
#    'alias': 'millennium-park-chicago',
#    'name': 'Millennium Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ChaxWprpD_HZZzQztouB1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millennium-park-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1273,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.88339, 'longitude': -87.6218446},
#    'transactions': [],
#    'location': {'address1': '201 E Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60602',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['201 E Randolph St', 'Chicago, IL 60602']},
#    'phone': '+13127421168',
#    'display_phone': '(312) 742-1168',
#    'distance': 5223.3300002387405},
#   {'id': 'bQaiow1WcwwSODUo9hHOMQ',
#    'alias': 'rpm-italian-chicago',
#    'name': 'RPM Italian',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8kxrNBhYHuYi_VveiczxgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rpm-italian-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3305,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8909608540557,
#     'longitude': -87.6300418625656},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '52 W Illinois St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['52 W Illinois St', 'Chicago, IL 60654']},
#    'phone': '+13122221888',
#    'display_phone': '(312) 222-1888',
#    'distance': 4253.689761756825},
#   {'id': 'Z2nOMPedr7XYhgYhILJjEA',
#    'alias': 'piece-brewery-and-pizzeria-chicago',
#    'name': 'Piece Brewery and Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gr8YXZHbC_KaQKP_lYVvxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piece-brewery-and-pizzeria-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3655,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9103256994423,
#     'longitude': -87.6760850295053},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1927 W North Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1927 W North Ave', 'Chicago, IL 60622']},
#    'phone': '+17737724422',
#    'display_phone': '(773) 772-4422',
#    'distance': 591.0619431782094},
#   {'id': 'mvFimrcREBIDo-pLAhMfNg',
#    'alias': 'avec-chicago-chicago',
#    'name': 'Avec - Chicago',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/miJ7tOnQqa-eQPDDc5MSIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avec-chicago-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2258,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.884290441849,
#     'longitude': -87.6433979433133},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '615 W Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60661',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['615 W Randolph St', 'Chicago, IL 60661']},
#    'phone': '+13123772002',
#    'display_phone': '(312) 377-2002',
#    'distance': 3671.0074926011484},
#   {'id': 'B_04jjMZjeGGKjaPcR3Kig',
#    'alias': 'three-dots-and-a-dash-chicago',
#    'name': 'Three Dots and A Dash',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J6JaUBHYRP01ZhvSh7uyag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-dots-and-a-dash-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3478,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8904391303273,
#     'longitude': -87.6306027367742},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '435 N Clark St',
#     'address2': 'Back alley on Hubbard St',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['435 N Clark St',
#      'Back alley on Hubbard St',
#      'Chicago, IL 60654']},
#    'phone': '+13126104220',
#    'display_phone': '(312) 610-4220',
#    'distance': 4232.7281042256345},
#   {'id': '9SY1qjFBIo8W48W6OTGWGg',
#    'alias': 'batter-and-berries-chicago',
#    'name': 'Batter & Berries',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ev75qiO3pUuHgmc6VuT0sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/batter-and-berries-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3038,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9315605, 'longitude': -87.6577911},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2748 N Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2748 N Lincoln Ave', 'Chicago, IL 60614']},
#    'phone': '+17732487710',
#    'display_phone': '(773) 248-7710',
#    'distance': 3372.977864065031},
#   {'id': 'f1P5hZSitUEAC-mtXlBB7w',
#    'alias': 'del-seoul-chicago',
#    'name': 'Del Seoul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XDUODSaUwEEJYuVA7IuH7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/del-seoul-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2200,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.929444, 'longitude': -87.643016},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2568 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2568 N Clark St', 'Chicago, IL 60614']},
#    'phone': '+17732484227',
#    'display_phone': '(773) 248-4227',
#    'distance': 3944.411852998117},
#   {'id': 'q7SQnw2xVHjWuyQXL3VHUg',
#    'alias': 'kai-zan-chicago',
#    'name': 'KAI ZAN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UQMQ7klk0gZkUM8Vpk1GRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kai-zan-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1104,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8955051374998,
#     'longitude': -87.6915407180786},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '2557 W Chicago Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2557 W Chicago Ave', 'Chicago, IL 60622']},
#    'phone': '+17732785776',
#    'display_phone': '(773) 278-5776',
#    'distance': 1565.9738189879604},
#   {'id': 'F7IQngaDDBgYvhA3U31q-g',
#    'alias': 'irazú-costa-rican-restaurant-and-catering-chicago-7',
#    'name': 'Irazú Costa Rican Restaurant & Catering',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nmi1BdOCjuJvpYvDNwOIUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iraz%C3%BA-costa-rican-restaurant-and-catering-chicago-7?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2266,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9151045993531,
#     'longitude': -87.6846393244315},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1865 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1865 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17732525687',
#    'display_phone': '(773) 252-5687',
#    'distance': 1243.605164590373},
#   {'id': 'LMaoM2Ue2BR_HI9ba3JsZg',
#    'alias': 'the-publican-chicago',
#    'name': 'The Publican',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q8VkzZwadgClxVdnL7_V1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-publican-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3290,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.886644, 'longitude': -87.648765},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '837 W Fulton Market',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['837 W Fulton Market', 'Chicago, IL 60607']},
#    'phone': '+13127339555',
#    'display_phone': '(312) 733-9555',
#    'distance': 3162.284756235595},
#   {'id': 'dux6UvpMGJuHquFA3JfR3A',
#    'alias': 'green-street-smoked-meats-chicago',
#    'name': 'Green Street Smoked Meats',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vREgFglrHV6kxyDjp9fPLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-street-smoked-meats-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1804,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.883623, 'longitude': -87.648907},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '112 N Green St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['112 N Green St', 'Chicago, IL 60607']},
#    'phone': '+13127540431',
#    'display_phone': '(312) 754-0431',
#    'distance': 3382.315033568261},
#   {'id': 'oEFJ29zAQaCNnQzebHQvpg',
#    'alias': 'the-violet-hour-chicago',
#    'name': 'The Violet Hour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q1WFBlYZj97ttatb-e6epQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-violet-hour-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2231,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.909095, 'longitude': -87.677829},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1520 N Damen Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1520 N Damen Ave', 'Chicago, IL 60622']},
#    'phone': '+17732521500',
#    'display_phone': '(773) 252-1500',
#    'distance': 437.66641406616156},
#   {'id': 'F2NBch93KPaQdM_x0Fs2VQ',
#    'alias': 'ninis-deli-chicago',
#    'name': "Nini's Deli",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Rep6irkZ1DHGdx58OX9vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ninis-deli-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 864,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.89235, 'longitude': -87.66198},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '543 N Noble St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60642',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['543 N Noble St', 'Chicago, IL 60642']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1930.8004265872505},
#   {'id': 't2nXebM7aqTj_qq6saZ89g',
#    'alias': 'eataly-chicago-chicago-6',
#    'name': 'Eataly Chicago',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hzab5WCKenxT07OGTlNCZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-chicago-chicago-6?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 3915,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.892335432963,
#     'longitude': -87.6262607945148},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '43 E Ohio St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['43 E Ohio St', 'Chicago, IL 60611']},
#    'phone': '+13125218700',
#    'display_phone': '(312) 521-8700',
#    'distance': 4494.921888413769},
#   {'id': '4i1Ny2zIE1VJSU9gLMkHqg',
#    'alias': 'lula-cafe-chicago-3',
#    'name': 'Lula Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4dII0KeWQfO5IZ5QHYqBWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lula-cafe-chicago-3?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1993,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.927668036295, 'longitude': -87.706845233929},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2537 N Kedzie Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2537 N Kedzie Blvd', 'Chicago, IL 60647']},
#    'phone': '+17734899554',
#    'display_phone': '(773) 489-9554',
#    'distance': 3471.884150522768},
#   {'id': 'm5_GCJP2W4zEJnyVgxa3eA',
#    'alias': 'longman-and-eagle-chicago',
#    'name': 'Longman & Eagle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nkFuSeLKVdj4EYFWZFahuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/longman-and-eagle-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2472,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.930156679293, 'longitude': -87.707222394898},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2657 N Kedzie Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2657 N Kedzie Ave', 'Chicago, IL 60647']},
#    'phone': '+17732767110',
#    'display_phone': '(773) 276-7110',
#    'distance': 3696.8474541264895},
#   {'id': '1hJYOI26FjCQ-Ce6iKAvug',
#    'alias': 'cafecito-chicago',
#    'name': 'Cafecito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ELyeA-gd8M0xIhyRiID85Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafecito-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2021,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.882416, 'longitude': -87.633641},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7 N Wells',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60606',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['7 N Wells', 'Chicago, IL 60606']},
#    'phone': '+13122634750',
#    'display_phone': '(312) 263-4750',
#    'distance': 4442.308762840083},
#   {'id': 'dKcO9OQ44RPRlkWe-vToFA',
#    'alias': 'shaws-crab-house-chicago',
#    'name': "Shaw's Crab House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TnS5biyTKb-iVRvDZ1yDMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shaws-crab-house-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2362,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8899414, 'longitude': -87.6273507},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '21 E Hubbard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['21 E Hubbard St', 'Chicago, IL 60611']},
#    'phone': '+13125272722',
#    'display_phone': '(312) 527-2722',
#    'distance': 4520.889564520181},
#   {'id': 'QNbWTNuAEMWOurHN8rMXnA',
#    'alias': 'chicago-pizza-and-oven-grinder-company-chicago',
#    'name': 'Chicago Pizza And Oven Grinder Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z_sI1ECW94akXvlTlNJruw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chicago-pizza-and-oven-grinder-company-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2693,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92084, 'longitude': -87.63721},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2121 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2121 N Clark St', 'Chicago, IL 60614']},
#    'phone': '+17732482570',
#    'display_phone': '(773) 248-2570',
#    'distance': 3773.5287713634652},
#   {'id': 'XKUZV9O2sRFLDIpAmwmG5g',
#    'alias': 'boka-chicago',
#    'name': 'Boka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vwZ5WBrKuUyTpDf0YxftBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boka-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1558,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9135158, 'longitude': -87.6480859},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '1729 N Halsted St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1729 N Halsted St', 'Chicago, IL 60614']},
#    'phone': '+13123376070',
#    'display_phone': '(312) 337-6070',
#    'distance': 2625.8826888696403},
#   {'id': 'zXDVdB7jofrt1IWODlOtUA',
#    'alias': 'beatrix-chicago-10',
#    'name': 'Beatrix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/d6i7SDYArbI77ezoCgqIfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beatrix-chicago-10?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2105,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.891492, 'longitude': -87.630833},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '519 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60654',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['519 N Clark St', 'Chicago, IL 60654']},
#    'phone': '+13122841377',
#    'display_phone': '(312) 284-1377',
#    'distance': 4171.063556152603},
#   {'id': 'lgjRFg3M-1N416W41DHsTQ',
#    'alias': 'ramen-wasabi-chicago',
#    'name': 'Ramen Wasabi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Tv5wtUME7PQRPjwf5tQCdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-wasabi-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2010,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9195063, 'longitude': -87.6915015},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2101 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2101 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17732278180',
#    'display_phone': '(773) 227-8180',
#    'distance': 1958.8406563289725},
#   {'id': '_d5Br6nZWpBNwL-4isroJA',
#    'alias': 'yuzu-sushi-and-robata-grill-chicago',
#    'name': 'Yuzu Sushi & Robata Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xy3W0At5Em7gPeSomiv_Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuzu-sushi-and-robata-grill-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1794,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.89569, 'longitude': -87.67172},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1751 W Chicago Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1751 W Chicago Ave', 'Chicago, IL 60622']},
#    'phone': '+13126664100',
#    'display_phone': '(312) 666-4100',
#    'distance': 1154.6192375859011},
#   {'id': '7vsOVA4wrHP6f3DMQdD8og',
#    'alias': 'volare-ristorante-italiano-chicago',
#    'name': 'Volare Ristorante Italiano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wxlYbKxJ2ZOYntKELd4xCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/volare-ristorante-italiano-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2325,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8915901798304,
#     'longitude': -87.6225186472213},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '201 E Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['201 E Grand Ave', 'Chicago, IL 60611']},
#    'phone': '+13124109900',
#    'display_phone': '(312) 410-9900',
#    'distance': 4814.997711304708},
#   {'id': 'JfNZVzh052lwZKpIMgsA1g',
#    'alias': 'garfield-park-conservatory-chicago',
#    'name': 'Garfield Park Conservatory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QKVGRMuMrXxkZ1nR3_Zt8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garfield-park-conservatory-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 669,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'},
#     {'alias': 'hiking', 'title': 'Hiking'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.8864959, 'longitude': -87.717822},
#    'transactions': [],
#    'location': {'address1': '300 N Central Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60624',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['300 N Central Park Ave', 'Chicago, IL 60624']},
#    'phone': '+17736381766',
#    'display_phone': '(773) 638-1766',
#    'distance': 3911.41732602952},
#   {'id': 'o54U2VkQama8FI30qDkWvw',
#    'alias': 'the-chicago-diner-lakeview-chicago-2',
#    'name': 'The Chicago Diner, Lakeview',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AcBbgiD7gYXuEdjHUCmlbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chicago-diner-lakeview-chicago-2?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2185,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9440163, 'longitude': -87.6491359},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3411 N Halsted St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3411 N Halsted St', 'Chicago, IL 60657']},
#    'phone': '+17739356696',
#    'display_phone': '(773) 935-6696',
#    'distance': 4927.308715386131},
#   {'id': 'cxAkuwv7p4gm4Coixw7h9A',
#    'alias': 'lou-malnatis-pizzeria-chicago-9',
#    'name': "Lou Malnati's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vZVADYrvKuC8iKrczzrdIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lou-malnatis-pizzeria-chicago-9?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 2769,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.871566, 'longitude': -87.627275},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '805 S State St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60605',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['805 S State St', 'Chicago, IL 60605']},
#    'phone': '+13127861000',
#    'display_phone': '(312) 786-1000',
#    'distance': 5605.468450285993},
#   {'id': '9mhqcimD0CYvqxzfj_VXnQ',
#    'alias': 'little-bad-wolf-chicago',
#    'name': 'Little Bad Wolf',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cf_ZeAt323eQv83zdhxASA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-bad-wolf-chicago?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1761,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.983356, 'longitude': -87.669057},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1541 W Bryn Mawr Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60660',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1541 W Bryn Mawr Ave', 'Chicago, IL 60660']},
#    'phone': '+17739426399',
#    'display_phone': '(773) 942-6399',
#    'distance': 8724.846825852152},
#   {'id': 'cyoEeLb5rc9ZAeTO2dkEUQ',
#    'alias': 'do-rite-donuts-and-chicken-chicago-4',
#    'name': 'Do-Rite Donuts & Chicken',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9NAV8p9Y_igm45R8b1NicQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/do-rite-donuts-and-chicken-chicago-4?adjust_creative=ArHFQ4-MFBX1gvK4LtYDdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ArHFQ4-MFBX1gvK4LtYDdQ',
#    'review_count': 1292,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.894028, 'longitude': -87.6213298},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '233 E Erie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60611',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['233 E Erie St', 'Chicago, IL 60611']},
#    'phone': '+13123441374',
#    'display_phone': '(312) 344-1374',
#    'distance': 4832.0145576226805}],
#  'total': 8600,
#  'region': {'center': {'longitude': -87.67776489257812,
#    'latitude': 41.90515925618311}}}

# %%
#pull restaurant data into a dataframe
zip_code = []
name = []
rating = []
food_type = []
lat = []
lng = []
review_count = []

for business in chicago_data["businesses"]:
    name.append(business["name"])
    rating.append(business["rating"])
    zip_code.append(business["location"]["zip_code"])
    food_type.append(business["categories"][0]["title"])
    review_count.append(business["review_count"])
    lat.append(business["coordinates"]["latitude"])
    lng.append(business["coordinates"]["longitude"])

# %%
name
# Out:
# ['Girl & The Goat',
#  'Wildberry Pancakes and Cafe',
#  'Au Cheval',
#  'The Purple Pig',
#  "Lou Malnati's Pizzeria",
#  'Art Institute of Chicago',
#  "Bavette's Bar & Boeuf",
#  'Cafe Ba-Ba-Reeba!',
#  'Smoque BBQ',
#  'Little Goat Diner',
#  "Pequod's Pizzeria",
#  'Quartino Ristorante',
#  'Alinea',
#  "Kuma's Corner - Belmont",
#  "Joe's Seafood, Prime Steak & Stone Crab",
#  'Crisp',
#  "Portillo's Hot Dogs",
#  'Sapori Trattoria',
#  'Xoco',
#  "Molly's Cupcakes",
#  'The Gage',
#  'Millennium Park',
#  'RPM Italian',
#  'Piece Brewery and Pizzeria',
#  'Avec - Chicago',
#  'Three Dots and A Dash',
#  'Batter & Berries',
#  'Del Seoul',
#  'KAI ZAN',
#  'Irazú Costa Rican Restaurant & Catering',
#  'The Publican',
#  'Green Street Smoked Meats',
#  'The Violet Hour',
#  "Nini's Deli",
#  'Eataly Chicago',
#  'Lula Cafe',
#  'Longman & Eagle',
#  'Cafecito',
#  "Shaw's Crab House",
#  'Chicago Pizza And Oven Grinder Company',
#  'Boka',
#  'Beatrix',
#  'Ramen Wasabi',
#  'Yuzu Sushi & Robata Grill',
#  'Volare Ristorante Italiano',
#  'Garfield Park Conservatory',
#  'The Chicago Diner, Lakeview',
#  "Lou Malnati's Pizzeria",
#  'Little Bad Wolf',
#  'Do-Rite Donuts & Chicken']
