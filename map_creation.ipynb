# %%
#Import the necessary functions
from pprint import pprint
import pandas as pd 
import requests
import numpy as np
import gmaps

from config import yelp_key
from config import g_key

# %%
#import the csv file
data = pd.read_csv("data/yelp_inspection_merge.csv")
data
# Out:
#       Unnamed: 0          AKA Name Facility Type             Risk  \
# 0              0      AREPA GEORGE    Restaurant    Risk 1 (High)
# 1              1      AREPA GEORGE    Restaurant    Risk 1 (High)
# 2              2    GRAND LUX CAFE    Restaurant    Risk 1 (High)
# 3              3    GRAND LUX CAFE    Restaurant    Risk 1 (High)
# 4              4    GRAND LUX CAFE    Restaurant    Risk 1 (High)
# ...          ...               ...           ...              ...
# 4882        4882            SUBWAY    Restaurant    Risk 1 (High)
# 4883        4883       BURGER KING    Restaurant  Risk 2 (Medium)
# 4884        4884            SUBWAY    Restaurant    Risk 1 (High)
# 4885        4885         FIREWINGS    Restaurant  Risk 2 (Medium)
# 4886        4886  HANNAH'S BRETZEL    Restaurant    Risk 1 (High)
#
#                      Address      Zip  Year          Inspection Type Results  \
# 0         1552 N KEDZIE AVE   60651.0  2021                  Canvass    Pass
# 1         1552 N KEDZIE AVE   60651.0  2020                  Canvass    Pass
# 2          111 E ONTARIO ST   60611.0  2021     Short Form Complaint    Pass
# 3          111 E ONTARIO ST   60611.0  2021                Complaint    Fail
# 4          111 E ONTARIO ST   60611.0  2021  Complaint Re-Inspection    Pass
# ...                      ...      ...   ...                      ...     ...
# 4882         1449 E 57TH ST   60637.0  2020                  Canvass    Pass
# 4883  1323 W IRVING PARK RD   60613.0  2020                  Canvass    Pass
# 4884       1313 W TOUHY AVE   60626.0  2020                  Canvass    Pass
# 4885      4749 N PULASKI RD   60630.0  2020                  Canvass    Fail
# 4886     233 N MICHIGAN AVE   60601.0  2020                  Canvass    Pass
#
#                                              Violations  ...  \
# 0                                                   NaN  ...
# 1     47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 2                                                   NaN  ...
# 3     48. WAREWASHING FACILITIES: INSTALLED, MAINTAI...  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 4882  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 4883  54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILI...  ...
# 4884  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 4885  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 4886  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                      display_address               address1  \
# 0         ['1552 N Kedzie Ave', 'Chicago, IL 60651']      1552 N Kedzie Ave
# 1         ['1552 N Kedzie Ave', 'Chicago, IL 60651']      1552 N Kedzie Ave
# 2        ['600 N Michigan Ave', 'Chicago, IL 60611']     600 N Michigan Ave
# 3        ['600 N Michigan Ave', 'Chicago, IL 60611']     600 N Michigan Ave
# 4        ['600 N Michigan Ave', 'Chicago, IL 60611']     600 N Michigan Ave
# ...                                              ...                    ...
# 4882         ['1449 E 57th St', 'Chicago, IL 60637']         1449 E 57th St
# 4883  ['1323 W Irving Park Rd', 'Chicago, IL 60613']  1323 W Irving Park Rd
# 4884        ['7138 N Sheridan', 'Chicago, IL 60626']        7138 N Sheridan
# 4885      ['4749 N Pulaski Rd', 'Chicago, IL 60625']      4749 N Pulaski Rd
# 4886     ['233 N Michigan Ave', 'Chicago, IL 60601']     233 N Michigan Ave
#
#       address2  address3     city   latitude  longitude zip code  \
# 0          NaN       NaN  Chicago  41.909745 -87.707155    60651
# 1          NaN       NaN  Chicago  41.909745 -87.707155    60651
# 2          NaN       NaN  Chicago  41.892896 -87.624868    60611
# 3          NaN       NaN  Chicago  41.892896 -87.624868    60611
# 4          NaN       NaN  Chicago  41.892896 -87.624868    60611
# ...        ...       ...      ...        ...        ...      ...
# 4882       NaN       NaN  Chicago  41.791362 -87.589697    60637
# 4883       NaN       NaN  Chicago  41.954003 -87.663148    60613
# 4884       NaN       NaN  Chicago  42.012522 -87.663871    60626
# 4885       NaN       NaN  Chicago  41.967703 -87.727857    60625
# 4886       NaN       NaN  Chicago  41.887069 -87.622927    60601
#
#                restaurant_id  price_integer
# 0     3nOO3B9xoASM9XLzJfbHDg            2.0
# 1     3nOO3B9xoASM9XLzJfbHDg            2.0
# 2     HSvG0P-1Qt1G8avx7B3mCg            2.0
# 3     HSvG0P-1Qt1G8avx7B3mCg            2.0
# 4     HSvG0P-1Qt1G8avx7B3mCg            2.0
# ...                      ...            ...
# 4882  PaZPav1hn1_pC6p9njqStw            1.0
# 4883  _N2m4_nBGi9ZWTJxNpyDKg            1.0
# 4884  Nc5I2gCZs6oxW5qKf2_k4A            1.0
# 4885  2buCzOrPbuVkGWm0AUa-1g            NaN
# 4886  9htt8fKKKG07eBPszNMg4A            2.0
#
# [4887 rows x 32 columns]

# %%
#create a dataframe with a great rating
great_df = data.loc[data["rating"]>=4]
good_df = data.loc[data["rating"]< 4]
good_df = good_df.loc[good_df["rating"]>=2]
bad_df = data.loc[data["rating"] <2]

# %%
#create a map with the great dataframe
great_health = great_df.loc[great_df["Results"] == "Pass"]
bad_health = great_df.loc[great_df["Results"] =="Fail"]
vbad_health = bad_df.loc[bad_df["Results"]=="Fail"]
notbad_health = bad_df.loc[bad_df["Results"] == "Pass"]

#configure the gmaps
gmaps.configure(api_key=g_key)

# %%
green_locations = great_health[["Latitude", "Longitude"]]
yellow_locations = bad_health[["Latitude", "Longitude"]]
red_locations = vbad_health[["Latitude", "Longitude"]]
blue_locations = notbad_health[["Latitude", "Longitude"]]
# names = list(great_health["name"])                            
fig = gmaps.figure()
# marker = gmaps.marker_layer(green_locations)

# fig.add_layer(marker)
#change the color of the marker
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)

# new_markers = gmaps.marker_layer(orange_locations)

# fig.add_layer(new_markers)

yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color = "yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)

red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color="red")
fig.add_layer(red_symbols)

blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color="blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create maps individually for each type
green_locations = great_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
yellow_locations = bad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color="yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
red_locations = vbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color = "red")
fig.add_layer(red_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
blue_locations = notbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#potential maps I could make
#comparing the more popular zip codes and see which one has the most highest rated restaurants
great_health["Zip"].value_counts()
zip_code_60661 = great_health.loc[great_health["Zip"] == 60661]
data_60661 = data.loc[data["Zip"] == 60661]
zip_code_60661
# Out:
#       Unnamed: 0                  AKA Name Facility Type           Risk  \
# 759          759             NAF NAF GRILL    Restaurant  Risk 1 (High)
# 760          760             NAF NAF GRILL    Restaurant  Risk 1 (High)
# 1164        1164          MARKET CREATIONS    Restaurant  Risk 1 (High)
# 1165        1165          MARKET CREATIONS    Restaurant  Risk 1 (High)
# 1333        1333         THE HAPPY LOBSTER    Restaurant  Risk 1 (High)
# 1619        1619     MELI CAFE & JUICE BAR    Restaurant  Risk 1 (High)
# 1621        1621     MELI CAFE & JUICE BAR    Restaurant  Risk 1 (High)
# 2437        2437  DAWALI JERUSALEM KITCHEN    Restaurant  Risk 1 (High)
# 2438        2438  DAWALI JERUSALEM KITCHEN    Restaurant  Risk 1 (High)
# 3087        3087                   CUPITOL    Restaurant   Risk 3 (Low)
# 3088        3088                   CUPITOL    Restaurant   Risk 3 (Low)
# 4086        4086                      JIAN    Restaurant  Risk 1 (High)
# 4287        4287     JOKER'S CAJUN KITCHEN    Restaurant  Risk 1 (High)
# 4288        4288     JOKER'S CAJUN KITCHEN    Restaurant  Risk 1 (High)
# 4549        4549                     SEPIA    Restaurant  Risk 1 (High)
# 4596        4596                BACI AMORE    Restaurant  Risk 1 (High)
# 4715        4715                     PROXI    Restaurant  Risk 1 (High)
# 4817        4817            BOXCAR BETTY'S    Restaurant  Risk 1 (High)
#
#                     Address      Zip  Year        Inspection Type Results  \
# 759           14 S CLINTON   60661.0  2022  Canvass Re-Inspection    Pass
# 760           14 S CLINTON   60661.0  2022  Canvass Re-Inspection    Pass
# 1164        625 W ADAMS ST   60661.0  2022                License    Pass
# 1165        625 W ADAMS ST   60661.0  2022                License    Pass
# 1333      131 N CLINTON ST   60661.0  2022  Canvass Re-Inspection    Pass
# 1619  301-305 S HALSTED ST   60661.0  2022  Canvass Re-Inspection    Pass
# 1621  301-305 S HALSTED ST   60661.0  2020  Canvass Re-Inspection    Pass
# 2437    319 S JEFFERSON ST   60661.0  2021                Canvass    Pass
# 2438    319 S JEFFERSON ST   60661.0  2020                Canvass    Pass
# 3087         135 N CLINTON   60661.0  2021                License    Pass
# 3088         135 N CLINTON   60661.0  2021                License    Pass
# 4086      131 N CLINTON ST   60661.0  2020  Canvass Re-Inspection    Pass
# 4287      131 N CLINTON ST   60661.0  2021                Canvass    Pass
# 4288      131 N CLINTON ST   60661.0  2020                Canvass    Pass
# 4549    123 N JEFFERSON ST   60661.0  2020                Canvass    Pass
# 4596    321 S JEFFERSON ST   60661.0  2020                Canvass    Pass
# 4715     565 W RANDOLPH ST   60661.0  2020                Canvass    Pass
# 4817      500 W MADISON ST   60661.0  2020  Canvass Re-Inspection    Pass
#
#                                              Violations  ...  \
# 759                                                 NaN  ...
# 760                                                 NaN  ...
# 1164                                                NaN  ...
# 1165                                                NaN  ...
# 1333  58. ALLERGEN TRAINING AS REQUIRED - Comments: ...  ...
# 1619                                                NaN  ...
# 1621  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 2437  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2438  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3087                                                NaN  ...
# 3088                                                NaN  ...
# 4086  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 4287  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 4288  41. WIPING CLOTHS: PROPERLY USED & STORED - Co...  ...
# 4549  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 4596  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 4715                                                NaN  ...
# 4817                                                NaN  ...
#
#                                         display_address  \
# 759        ['309 W Washington St', 'Chicago, IL 60606']
# 760            ['14 S Clinton St', 'Chicago, IL 60661']
# 1164  ['233 S Wacker Dr', 'Fl 2', 'Willis Tower', 'C...
# 1165   ['1 S Franklin St', 'Fl 2', 'Chicago, IL 60606']
# 1333          ['131 N Clinton St', 'Chicago, IL 60661']
# 1619          ['301 S Halsted St', 'Chicago, IL 60661']
# 1621          ['301 S Halsted St', 'Chicago, IL 60661']
# 2437        ['319 S Jefferson St', 'Chicago, IL 60661']
# 2438        ['319 S Jefferson St', 'Chicago, IL 60661']
# 3087          ['135 N Clinton St', 'Chicago, IL 60661']
# 3088          ['135 N Clinton St', 'Chicago, IL 60661']
# 4086      ['131 N Clinton Street', 'Chicago, IL 60602']
# 4287  ['131 N Clinton St French Market', 'Chicago, I...
# 4288  ['131 N Clinton St French Market', 'Chicago, I...
# 4549        ['123 N Jefferson St', 'Chicago, IL 60661']
# 4596  ['321 S Jefferson St', 'Fl 1', 'Chicago, IL 60...
# 4715         ['565 W Randolph St', 'Chicago, IL 60661']
# 4817          ['500 W Madison St', 'Chicago, IL 60661']
#
#                             address1  address2      address3     city  \
# 759              309 W Washington St       NaN           NaN  Chicago
# 760                  14 S Clinton St       NaN           NaN  Chicago
# 1164                 233 S Wacker Dr      Fl 2  Willis Tower  Chicago
# 1165                 1 S Franklin St      Fl 2           NaN  Chicago
# 1333                131 N Clinton St       NaN           NaN  Chicago
# 1619                301 S Halsted St       NaN           NaN  Chicago
# 1621                301 S Halsted St       NaN           NaN  Chicago
# 2437              319 S Jefferson St       NaN           NaN  Chicago
# 2438              319 S Jefferson St       NaN           NaN  Chicago
# 3087                135 N Clinton St       NaN           NaN  Chicago
# 3088                135 N Clinton St       NaN           NaN  Chicago
# 4086            131 N Clinton Street       NaN           NaN  Chicago
# 4287  131 N Clinton St French Market       NaN           NaN  Chicago
# 4288  131 N Clinton St French Market       NaN           NaN  Chicago
# 4549              123 N Jefferson St       NaN           NaN  Chicago
# 4596              321 S Jefferson St      Fl 1           NaN  Chicago
# 4715               565 W Randolph St       NaN           NaN  Chicago
# 4817                500 W Madison St       NaN           NaN  Chicago
#
#        latitude  longitude zip code           restaurant_id  price_integer
# 759   41.883107 -87.635624    60606  8BXbNpuPz_WR92_LE8V8kQ            1.0
# 760   41.881335 -87.641368    60661  w6-s9rcX1aocHS0t68odjw            1.0
# 1164  41.878820 -87.635956    60606  IS8V9ivSWrmTm8wU-QS0Jg            1.0
# 1165  41.881546 -87.635054    60606  Em3GSPR2REgo6HFEmFkepQ            NaN
# 4816      500 W MADISON ST   60661.0  2020                  Canvass    Fail
# 4817      500 W MADISON ST   60661.0  2020    Canvass Re-Inspection    Pass
# 4818      500 W MADISON ST   60661.0  2020                  Canvass    Fail
#
#                                              Violations  ...  \
# 731                                                 NaN  ...
# 732                                                 NaN  ...
# 733   43. IN-USE UTENSILS: PROPERLY STORED - Comment...  ...
# 734   43. IN-USE UTENSILS: PROPERLY STORED - Comment...  ...
# 759                                                 NaN  ...
# 760                                                 NaN  ...
# 761   10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 762   10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 812   37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 813   10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 1163                                                NaN  ...
# 1164                                                NaN  ...
# 1165                                                NaN  ...
# 1215  58. ALLERGEN TRAINING AS REQUIRED - Comments: ...  ...
# 1216  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 1333  58. ALLERGEN TRAINING AS REQUIRED - Comments: ...  ...
# 1334  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 1390  57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAIN...  ...
# 1391  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 1392  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 1393                                                NaN  ...
# 1422                                                NaN  ...
# 1423  35. APPROVED THAWING METHODS USED - Comments: ...  ...
# 1618  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 1619                                                NaN  ...
# 1620  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  ...
# 1621  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 1647  41. WIPING CLOTHS: PROPERLY USED & STORED - Co...  ...
# 1648  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2165  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 2166  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 2437  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2438  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2471  5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  ...
# 2472  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2473  40. PERSONAL CLEANLINESS - Comments: FOOD HAND...  ...
# 2481  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2522  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 2813  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  ...
# 2946  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2947  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3087                                                NaN  ...
# 3088                                                NaN  ...
# 4086  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 4087  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 4287  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 4288  41. WIPING CLOTHS: PROPERLY USED & STORED - Co...  ...
# 4417                                                NaN  ...
# 4427  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 4549  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 4588  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4596  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 4715                                                NaN  ...
# 4815                                                NaN  ...
# 4816  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4817                                                NaN  ...
# 4818  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  ...
#
#                                         display_address  \
# 731   ['525 W Monroe St', 'Ste L1A', 'Chicago, IL 60...
# 732   ['311 S Wacker Dr', 'Lowr 100', 'Chicago, IL 6...
# 733   ['525 W Monroe St', 'Ste L1A', 'Chicago, IL 60...
# 734   ['311 S Wacker Dr', 'Lowr 100', 'Chicago, IL 6...
# 759        ['309 W Washington St', 'Chicago, IL 60606']
# 760            ['14 S Clinton St', 'Chicago, IL 60661']
# 761        ['309 W Washington St', 'Chicago, IL 60606']
# 762            ['14 S Clinton St', 'Chicago, IL 60661']
# 812           ['500 W Madison St', 'Chicago, IL 60661']
# 813           ['500 W Madison St', 'Chicago, IL 60661']
# 1163   ['101 N Wacker', 'Ste 103', 'Chicago, IL 60606']
# 1164  ['233 S Wacker Dr', 'Fl 2', 'Willis Tower', 'C...
# 1165   ['1 S Franklin St', 'Fl 2', 'Chicago, IL 60606']
# 1215        ['711 W Jackson Blvd', 'Chicago, IL 60661']
# 1216        ['711 W Jackson Blvd', 'Chicago, IL 60661']
# 1333          ['131 N Clinton St', 'Chicago, IL 60661']
# 1334          ['131 N Clinton St', 'Chicago, IL 60661']
# 1390       ['222 S Riverside Plz', 'Chicago, IL 60606']
# 1391       ['222 S Riverside Plz', 'Chicago, IL 60606']
# 1392       ['222 S Riverside Plz', 'Chicago, IL 60606']
# 1393       ['222 S Riverside Plz', 'Chicago, IL 60606']
# 1422  ['304 S Jefferson St', 'Ste A', 'Chicago, IL 6...
# 1423  ['304 S Jefferson St', 'Ste A', 'Chicago, IL 6...
# 1618          ['301 S Halsted St', 'Chicago, IL 60661']
# 1619          ['301 S Halsted St', 'Chicago, IL 60661']
# 1620          ['301 S Halsted St', 'Chicago, IL 60661']
# 1621          ['301 S Halsted St', 'Chicago, IL 60661']
# 1647             ['500 W Madison', 'Chicago, IL 60661']
# 1648             ['500 W Madison', 'Chicago, IL 60661']
# 2165        ['769 W Jackson Blvd', 'Chicago, IL 60661']
# 2166        ['769 W Jackson Blvd', 'Chicago, IL 60661']
# 2437        ['319 S Jefferson St', 'Chicago, IL 60661']
# 2438        ['319 S Jefferson St', 'Chicago, IL 60661']
# 2471          ['234 S Halsted St', 'Chicago, IL 60661']
# 2472          ['234 S Halsted St', 'Chicago, IL 60661']
# 2473          ['234 S Halsted St', 'Chicago, IL 60661']
# 2481            ['550 W Adams St', 'Chicago, IL 60661']
# 2522  ['225 S Canal St', 'Union Station', 'Chicago, ...
# 2813  ['500 W Madison St', 'Suite# F003', 'Chicago, ...
# 2946             ['567 W Lake St', 'Chicago, IL 60661']
# 2947             ['567 W Lake St', 'Chicago, IL 60661']
# 3087          ['135 N Clinton St', 'Chicago, IL 60661']
# 3088          ['135 N Clinton St', 'Chicago, IL 60661']
# 4086      ['131 N Clinton Street', 'Chicago, IL 60602']
# 4087      ['131 N Clinton Street', 'Chicago, IL 60602']
# 4287  ['131 N Clinton St French Market', 'Chicago, I...
# 4288  ['131 N Clinton St French Market', 'Chicago, I...
# 4417          ['131 N Clinton St', 'Chicago, IL 60661']
# 4427           ['200 N Jefferson', 'Chicago, IL 60601']
# 4549        ['123 N Jefferson St', 'Chicago, IL 60661']
# 4588          ['547 W Jackson St', 'Chicago, IL 60661']
# 4596  ['321 S Jefferson St', 'Fl 1', 'Chicago, IL 60...
# 4715         ['565 W Randolph St', 'Chicago, IL 60661']
# 4815          ['500 W Madison St', 'Chicago, IL 60661']
# 4816          ['500 W Madison St', 'Chicago, IL 60661']
# 4817          ['500 W Madison St', 'Chicago, IL 60661']
# 4818          ['500 W Madison St', 'Chicago, IL 60661']
#
#                             address1     address2       address3     city  \
# 731                  525 W Monroe St      Ste L1A            NaN  Chicago
# 732                  311 S Wacker Dr     Lowr 100            NaN  Chicago
# 733                  525 W Monroe St      Ste L1A            NaN  Chicago
# 734                  311 S Wacker Dr     Lowr 100            NaN  Chicago
# 759              309 W Washington St          NaN            NaN  Chicago
# 760                  14 S Clinton St          NaN            NaN  Chicago
# 761              309 W Washington St          NaN            NaN  Chicago
# 762                  14 S Clinton St          NaN            NaN  Chicago
# 812                 500 W Madison St          NaN            NaN  Chicago
# 813                 500 W Madison St          NaN            NaN  Chicago
# 1163                    101 N Wacker      Ste 103            NaN  Chicago
# 1164                 233 S Wacker Dr         Fl 2   Willis Tower  Chicago
# 1165                 1 S Franklin St         Fl 2            NaN  Chicago
# 1215              711 W Jackson Blvd          NaN            NaN  Chicago
# 3088  41.884411 -87.641116    60661  E7lQ87vssybaUZ27GJrGEg            NaN
# 4086  41.884095 -87.640859    60602  pNuDH4Fe7-zmBnVJEfrhTQ            NaN
# 4087  41.884095 -87.640859    60602  pNuDH4Fe7-zmBnVJEfrhTQ            NaN
# 4287  41.883969 -87.641075    60661  _-uJdueVCgR7zynardt-bA            NaN
# 4288  41.883969 -87.641075    60661  _-uJdueVCgR7zynardt-bA            NaN
# 4417  41.883948 -87.641075    60661  i4dZiuVEzWZPTIOZWIMG7w            1.0
# 4427  41.886094 -87.643154    60601  32xJ0Xxshxzy8XhXp2WnKQ            1.0
# 4549  41.883933 -87.642400    60661  mPFMi734NXkvLFotygLrCA            4.0
# 4588  41.877907 -87.641716    60661  UpOSpLNiOCvatrgoOy_i9A            NaN
# 4596  41.877360 -87.642030    60661  kemCe40obdtTHxvRGpk5jA            NaN
# 4715  41.884295 -87.642275    60661  7NjkcZVOFfw31A0mPBPSPQ            3.0
# 4815  41.882350 -87.640470    60661  dFgXPQCTpOn5z06CwRc_OA            NaN
# 4816  41.882350 -87.640470    60661  dFgXPQCTpOn5z06CwRc_OA            NaN
# 4817  41.882350 -87.640470    60661  k1VobLvWkn0magmj7KYfeg            1.0
# 4818  41.882350 -87.640470    60661  k1VobLvWkn0magmj7KYfeg            1.0
#
# [57 rows x 32 columns]

# %%
zip60661_locations = data_60661[["Latitude", "Longitude"]]
fig = gmaps.figure()
zip60661_symbols = gmaps.symbol_layer(zip60661_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(zip60661_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a map of the great rating restaurants in 60661
great_data_60661 = data_60661.loc[data_60661["rating"] > 4]
great60661_locations = great_data_60661[["Latitude", "Longitude"]]
fig = gmaps.figure()
great60661_symbols = gmaps.symbol_layer(great60661_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60661_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
data_60657 = data.loc[data["zip code"] == 60657]
data_60613 = data.loc[data["zip code"] == 60613]
great_data_60657 = data_60657[data_60657["rating"]>=4]
great_data_60613 = data_60613[data_60613["rating"]>=4]
data_60657
# Out:
#       Unnamed: 0                  AKA Name Facility Type             Risk  \
# 139          139            DOMINO'S PIZZA    Restaurant  Risk 2 (Medium)
# 199          199         MAISON PARISIENNE    Restaurant    Risk 1 (High)
# 200          200         MAISON PARISIENNE    Restaurant    Risk 1 (High)
# 201          201         MAISON PARISIENNE    Restaurant    Risk 1 (High)
# 206          206                    TANUKI    Restaurant    Risk 1 (High)
# ...          ...                       ...           ...              ...
# 4751        4751  UKAI JAPANESE RESTAURANT    Restaurant    Risk 1 (High)
# 4775        4775    STAN'S DONUTS & COFFEE    Restaurant  Risk 2 (Medium)
# 4776        4776    STAN'S DONUTS & COFFEE    Restaurant  Risk 2 (Medium)
# 4834        4834                    SUBWAY    Restaurant    Risk 1 (High)
# 4870        4870               SHAKE SHACK    Restaurant  Risk 2 (Medium)
#
#                     Address      Zip  Year        Inspection Type Results  \
# 139        3103 N CLARK ST   60657.0  2020              Complaint    Pass
# 199        3307 N CLARK ST   60657.0  2020  Canvass Re-Inspection    Pass
# 200        3307 N CLARK ST   60657.0  2021                Canvass    Pass
# 201        3307 N CLARK ST   60657.0  2020                Canvass    Fail
# 206   3006 N SHEFFIELD AVE   60657.0  2020  Canvass Re-Inspection    Pass
# ...                     ...      ...   ...                    ...     ...
# 4751    1059 W BELMONT AVE   60657.0  2020  Canvass Re-Inspection    Pass
# 4775       3300 N BROADWAY   60657.0  2020  Canvass Re-Inspection    Pass
# 4776       3300 N BROADWAY   60657.0  2020                Canvass    Fail
# 4834    2825 N ASHLAND AVE   60657.0  2020                Canvass    Pass
# 4870       3519 N CLARK ST   60657.0  2020              Complaint    Pass
#
#                                              Violations  ...  \
# 139   38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 199                                                 NaN  ...
# 200   16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 201   36. THERMOMETERS PROVIDED & ACCURATE - Comment...  ...
# 206                                                 NaN  ...
# ...                                                 ...  ...
# 4751                                                NaN  ...
# 4775                                                NaN  ...
# 4776  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4834  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 4870  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                         display_address              address1  \
# 139            ['3103 N Clark St', 'Chicago, IL 60657']       3103 N Clark St
# 199            ['3307 N Clark St', 'Chicago, IL 60657']       3307 N Clark St
# 200            ['3307 N Clark St', 'Chicago, IL 60657']       3307 N Clark St
# 201            ['3307 N Clark St', 'Chicago, IL 60657']       3307 N Clark St
# 206       ['3006 N Sheffield Ave', 'Chicago, IL 60657']  3006 N Sheffield Ave
# ...                                                 ...                   ...
# 4751        ['1059 W Belmont Ave', 'Chicago, IL 60657']    1059 W Belmont Ave
# 4775           ['3300 N Broadway', 'Chicago, IL 60657']       3300 N Broadway
# 4776           ['3300 N Broadway', 'Chicago, IL 60657']       3300 N Broadway
# 4834        ['2825 N Ashland Ave', 'Chicago, IL 60657']    2825 N Ashland Ave
# 4870  ['3519 North Clark St', 'Ste C105', 'Chicago, ...   3519 North Clark St
#
#       address2  address3     city   latitude  longitude zip code  \
# 139        NaN       NaN  Chicago  41.937978 -87.648880    60657
# 199        NaN       NaN  Chicago  41.942090 -87.651990    60657
# 200        NaN       NaN  Chicago  41.942090 -87.651990    60657
# 201        NaN       NaN  Chicago  41.942090 -87.651990    60657
# 206        NaN       NaN  Chicago  41.936547 -87.654151    60657
# ...        ...       ...      ...        ...        ...      ...
# 4751       NaN       NaN  Chicago  41.939695 -87.656164    60657
# 4775       NaN       NaN  Chicago  41.941969 -87.644614    60657
# 4776       NaN       NaN  Chicago  41.941969 -87.644614    60657
# 4834       NaN       NaN  Chicago  41.933205 -87.667806    60657
# 4870  Ste C105       NaN  Chicago  41.946300 -87.655420    60657
#
#                restaurant_id  price_integer
# 139   hwrBNgqg95B09sJpTqDUPg            1.0
# 199   5jbqjzdcQR9jNBTsmX8Xog            2.0
# 200   5jbqjzdcQR9jNBTsmX8Xog            2.0
# 201   5jbqjzdcQR9jNBTsmX8Xog            2.0
# 206   k81iqznYFEJtmmx6incxsg            2.0
# ...                      ...            ...
# 4751  forjLZnWO4KyRWH4y1W8KA            2.0
# 4775  XGVGPeCGLoCewbgHI6m2Bw            1.0
# 4776  XGVGPeCGLoCewbgHI6m2Bw            1.0
# 4834  hFfMA1pDFaiSDIlQTQI1LA            1.0
# 4870  f_OQPMtDEmF-_QnRljFWzA            2.0
#
# [236 rows x 32 columns]

# %%
#create a graph showing whether you should go north or south for a good restaurant before/after a cubs game
great60657_locations = great_data_60657[["Latitude", "Longitude"]]
great60613_locations = great_data_60613[["Latitude", "Longitude"]]
fig = gmaps.figure()
great60657_symbols = gmaps.symbol_layer(great60657_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60657_symbols)
great60613_symbols = gmaps.symbol_layer(great60613_locations, fill_color="red", stroke_color = "red")
fig.add_layer(great60613_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
just_ratings = pd.read_csv("data/yelp_csv/yelp_csv_CLEAN.csv")
just_ratings
# Out:
#       Unnamed: 0                        name       category  category_title  \
# 0              0             Tortas Frontera        mexican         Mexican
# 1              1             Farmer's Fridge          salad           Salad
# 2              2             Tortas Frontera        mexican         Mexican
# 3              3               Gaslight Club    newamerican  American (New)
# 4              4                    Big Bowl        chinese         Chinese
# ...          ...                         ...            ...             ...
# 6839        6839  The Dock At Montrose Beach    newamerican  American (New)
# 6840        6840     Wentworth Seafood House      bubbletea      Bubble Tea
# 6841        6841              Little Toasted    whiskeybars    Whiskey Bars
# 6842        6842          Dinner And A Movie  movietheaters          Cinema
# 6843        6843         Taqueria Traspasada        mexican         Mexican
#
#       rating price  review_count  \
# 0        4.0    $$          1395
# 1        4.5     $            62
# 2        4.0    $$          1321
# 3        3.5   $$$            99
# 4        2.0    $$            36
# ...      ...   ...           ...
# 6839     3.0    $$           316
# 6840     4.0    $$           125
# 6841     4.0    $$            70
# 6842     2.5    $$            17
# 6843     4.0     $           401
#
#                                         display_address  \
# 0     ['Terminal 3 - Gate K4', "10000 W O'Hare Ave",...
# 1     ['10000 Ohare Way', 'Terminal 3 Gate K6', 'Chi...
# 2     ["10000 W O'Hare Ave", 'Terminal 1 - Gate B11'...
# 3     ["Chicago O'Hare International Airport", "O'Ha...
# 4     ["10000 West O'hare Ave", 'Terminal 5; Gate M7...
# ...                                                 ...
# 6839  ['200 W Montrose Harbor Dr', 'Chicago, IL 60601']
# 6840      ['2229 S Wentworth Ave', 'Chicago, IL 60616']
# 6841           ['300 S Riverside', 'Chicago, IL 60606']
# 6842        ['2500 N Ashland Ave', 'Chicago, IL 60614']
# 6843         ['811 N Ashland Ave', 'Chicago, IL 60622']
#
#                                   address1            address2  \
# 0                     Terminal 3 - Gate K4  10000 W O'Hare Ave
# 1                          10000 Ohare Way                 NaN
# 2                       10000 W O'Hare Ave                 NaN
# 3     Chicago O'Hare International Airport                 NaN
# 4                    10000 West O'hare Ave                 NaN
# ...                                    ...                 ...
# 6839              200 W Montrose Harbor Dr                 NaN
# 6840                  2229 S Wentworth Ave                 NaN
# 6841                       300 S Riverside                 NaN
# 6842                    2500 N Ashland Ave                 NaN
# 6843                     811 N Ashland Ave                 NaN
#
#                                address3     city   latitude  longitude  \
# 0        Terminal 3 Concourse K Gate K4  Chicago  41.975438 -87.900137
# 1                    Terminal 3 Gate K6  Chicago  41.975234 -87.898719
# 2                 Terminal 1 - Gate B11  Chicago  41.980026 -87.906679
# 3     O'Hare Hilton Hotel - Lobby Level  Chicago  41.977965 -87.905173
# 4                   Terminal 5; Gate M7  Chicago  41.975103 -87.891350
# ...                                 ...      ...        ...        ...
# 6839                                NaN  Chicago  41.964596 -87.636395
# 6840                                NaN  Chicago  41.852301 -87.631849
# 6841                                NaN  Chicago  41.877410 -87.638760
# 6842                                NaN  Chicago  41.927070 -87.668560
# 6843                                NaN  Chicago  41.896330 -87.667050
#
#       zip code           restaurant_id  price_integer
# 0        60666  1zZvM7Zy__Oh533E4bt6_A            2.0
# 1        60666  4xQv1b1IFRsAWZu7yVLFrQ            1.0
# 2        60666  0k018u1PAtfmkNRYk04yCQ            2.0
# 3        60666  MywzBEKWjmt0bcNajKt8yw            3.0
# 4        60666  6VZwwWxBmxMsKd10AIOjxg            2.0
# ...        ...                     ...            ...
# 6839     60601  lf8WcC4IvzvmvlSmYIoi3Q            2.0
# 6840     60616  rVRMpovx68BZXTLedFwB5Q            2.0
# 6841     60606  IfQOHedYrGg9m9lXWE5NWw            2.0
# 6842     60614  v02hTCN65wPueVeZZniYPw            2.0
# 6843     60622  nTL9tlTqGr5-J68W-3Szww            1.0
#
# [6844 rows x 17 columns]

# %%
just_ratings_60657 = just_ratings.loc[just_ratings["rating"]>=3]
just_ratings_60613 = just_ratings.loc[just_ratings["rating"]>=3]
ratings_60657 = just_ratings_60657.loc[just_ratings_60657["zip code"] == 60657]
ratings_60613 = just_ratings_60613.loc[just_ratings_60613["zip code"] == 60613]

# %%
_60657_locations = ratings_60657[["latitude", "longitude"]]
_60613_locations = ratings_60613[["latitude", "longitude"]]
fig = gmaps.figure()
_60657_symbols = gmaps.symbol_layer(_60657_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(_60657_symbols)
_60613_symbols = gmaps.symbol_layer(_60613_locations, fill_color="red", stroke_color = "red")
fig.add_layer(_60613_symbols)
fig
# add review counts of over 100
#add different colors for different types of food
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a dataframe of 60657 and 60613 with 2-3 rating and a pass
beer_data = just_ratings.loc[just_ratings["rating"] >= 2]
beer_data = beer_data.loc[beer_data["rating"] <= 4]
# beer_data = beer_data.loc[beer_data["Facility Type"] =="bar"]
beer_data = beer_data.loc[beer_data["zip code"] == 60613]
beer_data = beer_data.loc[beer_data["category_title"].str.contains("Bar")]
beer_data
# Out:
#       Unnamed: 0                         name      category category_title  \
# 1894        1894      Smylie Brothers Brewing           bbq       Barbeque
# 1898        1898                   Nano Sushi         sushi     Sushi Bars
# 1913        1913       Pancake Cafe - Chicago          bars           Bars
# 1923        1923                      Fat Cat  cocktailbars  Cocktail Bars
# 1926        1926            Rizzo's Bar & Inn          bars           Bars
# 1927        1927                  The Piggery           bbq       Barbeque
# 1933        1933                 Holiday Club          bars           Bars
# 1946        1946                   Sushi Mura         sushi     Sushi Bars
# 1978        1978                F. O'Mahony's          bars           Bars
# 2015        2015           Bulerias Tapas Bar         tapas     Tapas Bars
# 2038        2038         Bernie's Tap & Grill          bars           Bars
# 2047        2047         Yak-Zies Bar & Grill    sportsbars    Sports Bars
# 2070        2070   A.J. Hudson's Public House    sportsbars    Sports Bars
# 2087        2087                      Jai-Yen         sushi     Sushi Bars
# 2108        2108                        Trace    sportsbars    Sports Bars
# 2133        2133                   The Dugout    sportsbars    Sports Bars
# 2164        2164                Casey Moran's           bbq       Barbeque
# 3413        3413    Brownstone Tavern & Grill    sportsbars    Sports Bars
# 3430        3430                The Globe Pub    sportsbars    Sports Bars
# 3465        3465                   Oakwood 83          bars           Bars
# 3803        3803         Swift & Son's Tavern          bars           Bars
# 3815        3815                  Smoke Daddy           bbq       Barbeque
# 3816        3816  Budweiser Brickhouse Tavern    sportsbars    Sports Bars
# 3897        3897            Toons Bar & Grill          bars           Bars
# 6614        6614                     Big Star       beerbar       Beer Bar
#
#       rating price  review_count  \
# 1894     3.5    $$            39
# 1898     4.0    $$           161
# 1913     3.5    $$           185
# 1923     3.5    $$           703
# 1926     3.5    $$            99
# 1927     3.5    $$           518
# 1933     3.5    $$           373
# 1946     4.0    $$           300
# 1978     3.5    $$           271
# 2015     3.5    $$           436
# 2038     3.5    $$           115
# 2047     3.0    $$           199
# 2070     3.5    $$           159
# 2087     3.5    $$           447
# 2108     3.0    $$           103
# 2133     3.0     $            61
# 2164     2.5    $$           227
# 3413     3.5    $$           481
# 3430     4.0    $$           449
# 3465     3.5     $            52
# 3803     3.5   NaN            64
# 3815     3.5    $$           223
# 3816     4.0    $$           166
# 3897     4.0    $$           245
# 6614     3.0    $$           259
#
#                                      display_address               address1  \
# 1894        ['3827 N Broadway', 'Chicago, IL 60613']        3827 N Broadway
# 1898    ['3955 N Broadway Ave', 'Chicago, IL 60613']    3955 N Broadway Ave
# 1913        ['3805 N Broadway', 'Chicago, IL 60613']        3805 N Broadway
# 1923    ['4840 N Broadway Ave', 'Chicago, IL 60613']    4840 N Broadway Ave
# 1926        ['3658 N Clark St', 'Chicago, IL 60613']        3658 N Clark St
# 1927  ['1625 W Irving Park Rd', 'Chicago, IL 60613']  1625 W Irving Park Rd
# 1933     ['4000 N Sheridan Rd', 'Chicago, IL 60613']     4000 N Sheridan Rd
# 1946   ['3647 N Southport Ave', 'Chicago, IL 60613']   3647 N Southport Ave
# 1978     ['3701 N Broadway St', 'Chicago, IL 60613']     3701 N Broadway St
# 2015     ['3656 N Ashland Ave', 'Chicago, IL 60613']     3656 N Ashland Ave
# 2038        ['3664 N Clark St', 'Chicago, IL 60613']        3664 N Clark St
# 2047        ['3710 N Clark St', 'Chicago, IL 60613']        3710 N Clark St
# 2070     ['3801 N Ashland Ave', 'Chicago, IL 60613']     3801 N Ashland Ave
# 2087     ['3736 N Broadway St', 'Chicago, IL 60613']     3736 N Broadway St
# 2108        ['3714 N Clark St', 'Chicago, IL 60613']        3714 N Clark St
# 2133       ['950 W Addison St', 'Chicago, IL 60613']       950 W Addison St
# 2164        ['3660 N Clark St', 'Chicago, IL 60613']        3660 N Clark St
# 3413     ['3937 N Lincoln Ave', 'Chicago, IL 60613']     3937 N Lincoln Ave
# 3430  ['1934 W Irving Park Rd', 'Chicago, IL 60613']  1934 W Irving Park Rd
# 3465    ['1959 W Montrose Ave', 'Chicago, IL 60613']    1959 W Montrose Ave
# 2164  FHHrWg5LHX5c5AL1tC5r0Q            2.0
# 3413  ACxKsayQAP9eCV2WIv_6Ww            2.0
# 3430  ijtyBBrKmxVkmmMzcVqOMQ            2.0
# 3465  ygtoZss_DEwal-cLnAoI2g            1.0
# 3803  -2l4IEiHcppZwqQ6HNIi_Q            NaN
# 3815  z_3LfLCLWSM8vaNvWOwUjA            2.0
# 3816  Os85pJjWUMyOmnkcI3PjHQ            2.0
# 3897  p8nvZAnNOqW8ojfhTnj0Kw            2.0
# 6614  hVUINnit4I2kR35KFDSNuQ            2.0

# %%
rest = ["Old Crow Smokehouse", "The Butcher’s Tap"]

# zip_downtown = downtown.loc[downtown["Zip"].isin(zips),:]
beer_data_other = just_ratings.loc[just_ratings["rating"] >= 2]
beer_data_other = beer_data_other.loc[beer_data_other["rating"] <= 4]
# beer_data_other = beer_data_other.loc[beer_data_other["Results"] =="Pass"]
beer_data_other = beer_data_other.loc[beer_data_other["zip code"] == 60657]
beer_data_other = beer_data_other.loc[beer_data_other["category_title"].str.contains("Bar")]
beer_data_other
beer_data_bar = beer_data_other.loc[beer_data_other["name"].isin(rest),:]
beer_data_bar
# Out:
#       Unnamed: 0                 name    category category_title  rating  \
# 2059        2059  Old Crow Smokehouse         bbq       Barbeque     3.0
# 3845        3845    The Butcher’s Tap  sportsbars    Sports Bars     3.5
#
#      price  review_count                                display_address  \
# 2059    $$           468       ['3506 N Clark St', 'Chicago, IL 60657']
# 3845    $$           224  ['3553 N Southport Ave', 'Chicago, IL 60657']
#
#                   address1 address2 address3     city   latitude  longitude  \
# 2059       3506 N Clark St      NaN      NaN  Chicago  41.945807 -87.655558
# 3845  3553 N Southport Ave      NaN      NaN  Chicago  41.946789 -87.663643
#
#       zip code           restaurant_id  price_integer
# 2059     60657  Mnfr146Brl4PvvDdKv8LsA            2.0
# 3845     60657  cmOyagGx7V6Z16C6t6qfyA            2.0

# %%
# beer_data_other = data.loc[data["rating"] >= 2]
# beer_data_other = beer_data_other.loc[beer_data_other["rating"] <= 4]
# beer_data_other = beer_data_other.loc[beer_data_other["Results"] =="Pass"]
# beer_data_other = beer_data_other.loc[beer_data_other["Zip"] == 60657]
# beer_data_other - beer_data_other.loc[beer_data_other[""]]
beer_data_other
# Out:
#       Unnamed: 0                                    name      category  \
# 92            92  Yellowtail Sushi Bar and Asian Kitchen         sushi
# 95            95                     Parrots Bar & Grill          bars
# 104          104                      Side Street Saloon      divebars
# 2029        2029                          Santa Baby Bar          bars
# 2030        2030                Lucky's Sandwich Company          bars
# 2059        2059                     Old Crow Smokehouse           bbq
# 2065        2065       Milt's Barbecue for the Perplexed           bbq
# 2088        2088                          Christmas Club          bars
# 2091        2091                     Shiawase Restaurant         sushi
# 2093        2093                                Wakamono         sushi
# 2106        2106                   Diva Thai & Sushi Bar         sushi
# 2141        2141                            The Pony Inn    sportsbars
# 3802        3802                            Happy Camper          bars
# 3845        3845                       The Butcher’s Tap    sportsbars
# 3849        3849                                  Tanuki         sushi
# 3870        3870                          Rocks Lakeview    sportsbars
# 3905        3905          Sheffield's Wine & Beer Garden          bars
# 3919        3919                     Stretch Bar & Grill    sportsbars
# 5969        5969                       Farm Bar Lakeview          bars
# 6306        6306                                    Wood          bars
# 6577        6577            Frasca Pizzeria and Wine Bar     wine_bars
# 6584        6584                      Nola Bar & Kitchen  cocktailbars
# 6686        6686                             The Reveler          bars
#
#      category_title  rating price  review_count  \
# 92       Sushi Bars     4.0    $$           346
# 95             Bars     4.0     $            70
# 104       Dive Bars     4.0     $           123
# 2029           Bars     3.0    $$           174
# 2030           Bars     3.5    $$           535
# 2059       Barbeque     3.0    $$           468
# 2065       Barbeque     3.5    $$           317
# 2088           Bars     3.0    $$            20
# 2091     Sushi Bars     4.0    $$           162
# 2093     Sushi Bars     3.5    $$           531
# 2106     Sushi Bars     3.0    $$           361
# 2141    Sports Bars     3.5    $$           264
# 3802           Bars     4.0    $$           249
# 3845    Sports Bars     3.5    $$           224
# 3849     Sushi Bars     4.0    $$           321
# 3870    Sports Bars     3.5    $$           617
# 3905           Bars     3.5    $$           748
# 3919    Sports Bars     4.0    $$           159
# 5969           Bars     4.0    $$           355
# 6306           Bars     4.0    $$           595
# 6577      Wine Bars     4.0    $$           766
# 6584  Cocktail Bars     4.0    $$           128
# 6686           Bars     3.5   NaN            72
#
#                                      display_address               address1  \
# 92       ['3136 N Broadway St', 'Chicago, IL 60657']     3136 N Broadway St
# 95     ['754 W Wellington Ave', 'Chicago, IL 60657']   754 W Wellington Ave
# 104        ['1456 W George St', 'Chicago, IL 60657']       1456 W George St
# 2029        ['3505 N Clark St', 'Chicago, IL 60657']        3505 N Clark St
# 2030        ['3472 N Clark St', 'Chicago, IL 60657']        3472 N Clark St
# 2059        ['3506 N Clark St', 'Chicago, IL 60657']        3506 N Clark St
# 2065     ['3411 N Broadway St', 'Chicago, IL 60657']     3411 N Broadway St
# 2088        ['3462 N Clark St', 'Chicago, IL 60657']        3462 N Clark St
# 2091     ['1059 W Belmont Ave', 'Chicago, IL 60657']     1059 W Belmont Ave
# 2093    ['3313 N Broadway Ave', 'Chicago, IL 60657']    3313 N Broadway Ave
# 2106      ['3542 N Halsted St', 'Chicago, IL 60657']      3542 N Halsted St
# 2141     ['1638 W Belmont Ave', 'Chicago, IL 60657']     1638 W Belmont Ave
# 3802        ['3458 N Clark St', 'Chicago, IL 60657']        3458 N Clark St
# 3845   ['3553 N Southport Ave', 'Chicago, IL 60657']   3553 N Southport Ave
# 3849   ['3006 N Sheffield Ave', 'Chicago, IL 60657']   3006 N Sheffield Ave
# 3870     ['3463 N Broadway St', 'Chicago, IL 60657']     3463 N Broadway St
# 3905   ['3258 N Sheffield Ave', 'Chicago, IL 60657']   3258 N Sheffield Ave
# 3919        ['3485 N Clark St', 'Chicago, IL 60657']        3485 N Clark St
# 5969  ['1300 W Wellington Ave', 'Chicago, IL 60657']  1300 W Wellington Ave
# 6306      ['3335 N Halsted St', 'Chicago, IL 60657']      3335 N Halsted St
# 6577      ['3358 N Paulina St', 'Chicago, IL 60657']      3358 N Paulina St
# 6584        ['3481 N Clark St', 'Chicago, IL 60657']        3481 N Clark St
# %%
#create a dataframe with specific restaurants to turn into markers
beer_data
place = ["Budweiser Brickhouse Tavern"]
beer_data_bar2 = beer_data.loc[beer_data["name"].isin(place),:]
beer_data_bar2
# Out:
#       Unnamed: 0                         name    category category_title  \
# 3816        3816  Budweiser Brickhouse Tavern  sportsbars    Sports Bars
#
#       rating price  review_count                           display_address  \
# 3816     4.0    $$           166  ['3647 N Clark St', 'Chicago, IL 60613']
#
#              address1 address2 address3     city   latitude  longitude  \
# 3816  3647 N Clark St      NaN      NaN  Chicago  41.948647 -87.657096
#
#       zip code           restaurant_id  price_integer
# 3816     60613  Os85pJjWUMyOmnkcI3PjHQ            2.0

# %%
beer_60613 = beer_data[["latitude", "longitude"]]
beer_60657 = beer_data_other[["latitude", "longitude"]]
beer_marker = beer_data_bar[["latitude", "longitude"]]
beer_marker_2 = beer_data_bar2[["latitude", "longitude"]]
fig = gmaps.figure()
great60613_symbols = gmaps.symbol_layer(beer_60613, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60613_symbols)
great60657_symbols = gmaps.symbol_layer(beer_60657, fill_color="red", stroke_color = "red")
fig.add_layer(great60657_symbols)
marker_1 = gmaps.marker_layer(beer_marker)
fig.add_layer(marker_1)
marker_2 = gmaps.marker_layer(beer_marker_2)
fig.add_layer(marker_2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a dataframe of 60657 and 60613 with 2-3 rating and a pass
beer_data = just_ratings.loc[just_ratings["rating"] >= 2]
beer_data = beer_data.loc[beer_data["rating"] <= 4]
# beer_data = beer_data.loc[beer_data["Facility Type"] =="bar"]
beer_data = beer_data.loc[beer_data["zip code"] == 60613]
beer_data = beer_data.loc[beer_data["category_title"].str.contains("Bar")]
beer_data
# Out:
#       Unnamed: 0                         name      category category_title  \
# 1894        1894      Smylie Brothers Brewing           bbq       Barbeque
# 1898        1898                   Nano Sushi         sushi     Sushi Bars
# 1913        1913       Pancake Cafe - Chicago          bars           Bars
# 1923        1923                      Fat Cat  cocktailbars  Cocktail Bars
# 1926        1926            Rizzo's Bar & Inn          bars           Bars
# 1927        1927                  The Piggery           bbq       Barbeque
# 1933        1933                 Holiday Club          bars           Bars
# 1946        1946                   Sushi Mura         sushi     Sushi Bars
# 1978        1978                F. O'Mahony's          bars           Bars
# 2015        2015           Bulerias Tapas Bar         tapas     Tapas Bars
# 2038        2038         Bernie's Tap & Grill          bars           Bars
# 2047        2047         Yak-Zies Bar & Grill    sportsbars    Sports Bars
# 2070        2070   A.J. Hudson's Public House    sportsbars    Sports Bars
# 2087        2087                      Jai-Yen         sushi     Sushi Bars
# 2108        2108                        Trace    sportsbars    Sports Bars
# 2133        2133                   The Dugout    sportsbars    Sports Bars
# 2164        2164                Casey Moran's           bbq       Barbeque
# 3413        3413    Brownstone Tavern & Grill    sportsbars    Sports Bars
# 3430        3430                The Globe Pub    sportsbars    Sports Bars
# 3465        3465                   Oakwood 83          bars           Bars
# 3803        3803         Swift & Son's Tavern          bars           Bars
# 3815        3815                  Smoke Daddy           bbq       Barbeque
# 3816        3816  Budweiser Brickhouse Tavern    sportsbars    Sports Bars
# 3897        3897            Toons Bar & Grill          bars           Bars
# 6614        6614                     Big Star       beerbar       Beer Bar
#
#       rating price  review_count  \
# 1894     3.5    $$            39
# 1898     4.0    $$           161
# 1913     3.5    $$           185
# 1923     3.5    $$           703
# 1926     3.5    $$            99
# 1927     3.5    $$           518
# 1933     3.5    $$           373
# 1946     4.0    $$           300
# 1978     3.5    $$           271
# 2015     3.5    $$           436
# 2038     3.5    $$           115
# 2047     3.0    $$           199
# 2070     3.5    $$           159
# 2087     3.5    $$           447
# 2108     3.0    $$           103
# 2133     3.0     $            61
# 2164     2.5    $$           227
# 3413     3.5    $$           481
# 3430     4.0    $$           449
# 3465     3.5     $            52
# 3803     3.5   NaN            64
# 3815     3.5    $$           223
# 3816     4.0    $$           166
# 3897     4.0    $$           245
# 6614     3.0    $$           259
#
#                                      display_address               address1  \
# 1894        ['3827 N Broadway', 'Chicago, IL 60613']        3827 N Broadway
# 1898    ['3955 N Broadway Ave', 'Chicago, IL 60613']    3955 N Broadway Ave
# 1913        ['3805 N Broadway', 'Chicago, IL 60613']        3805 N Broadway
# 1923    ['4840 N Broadway Ave', 'Chicago, IL 60613']    4840 N Broadway Ave
# 1926        ['3658 N Clark St', 'Chicago, IL 60613']        3658 N Clark St
# 1927  ['1625 W Irving Park Rd', 'Chicago, IL 60613']  1625 W Irving Park Rd
# 1933     ['4000 N Sheridan Rd', 'Chicago, IL 60613']     4000 N Sheridan Rd
# 1946   ['3647 N Southport Ave', 'Chicago, IL 60613']   3647 N Southport Ave
# 1978     ['3701 N Broadway St', 'Chicago, IL 60613']     3701 N Broadway St
# 2015     ['3656 N Ashland Ave', 'Chicago, IL 60613']     3656 N Ashland Ave
# 2038        ['3664 N Clark St', 'Chicago, IL 60613']        3664 N Clark St
# 2047        ['3710 N Clark St', 'Chicago, IL 60613']        3710 N Clark St
# 2070     ['3801 N Ashland Ave', 'Chicago, IL 60613']     3801 N Ashland Ave
# 2087     ['3736 N Broadway St', 'Chicago, IL 60613']     3736 N Broadway St
# 2108        ['3714 N Clark St', 'Chicago, IL 60613']        3714 N Clark St
# 2133       ['950 W Addison St', 'Chicago, IL 60613']       950 W Addison St
# 2164        ['3660 N Clark St', 'Chicago, IL 60613']        3660 N Clark St
# 3413     ['3937 N Lincoln Ave', 'Chicago, IL 60613']     3937 N Lincoln Ave
# 3430  ['1934 W Irving Park Rd', 'Chicago, IL 60613']  1934 W Irving Park Rd
# 3465    ['1959 W Montrose Ave', 'Chicago, IL 60613']    1959 W Montrose Ave
# 3803        ['3600 N Clark St', 'Chicago, IL 60613']        3600 N Clark St
# 3815        ['3636 N Clark St', 'Chicago, IL 60613']        3636 N Clark St
# 3816        ['3647 N Clark St', 'Chicago, IL 60613']        3647 N Clark St
# 3897   ['3857 N Southport Ave', 'Chicago, IL 60613']   3857 N Southport Ave
# 6614        ['3640 N Clark St', 'Chicago, IL 60613']        3640 N Clark St
#
#      address2 address3     city   latitude  longitude  zip code  \
# 1894      NaN      NaN  Chicago  41.952187 -87.649487     60613
# 1898      NaN      NaN  Chicago  41.953778 -87.650012     60613
# %%
beer_60613 = beer_data[["latitude", "longitude"]]
beer_60657 = beer_data_other[["latitude", "longitude"]]
fig = gmaps.figure()
great60613_symbols = gmaps.symbol_layer(beer_60613, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60613_symbols)
great60657_symbols = gmaps.symbol_layer(beer_60657, fill_color="red", stroke_color = "red")
fig.add_layer(great60657_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#all by yourself data frame
# yourself = data.loc[data["rating"]< 2]
# yourself = yourself.loc[yourself["Results"] == "Fail"]
yourself = data.loc[data["Zip"] == 60657]
yourself = yourself.loc[yourself["price_integer"] <2]
# yourself = yourself.loc[yourself["Results"]== "Fail"]
yourself
# Out:
#       Unnamed: 0                AKA Name Facility Type             Risk  \
# 139          139          DOMINO'S PIZZA    Restaurant  Risk 2 (Medium)
# 335          335             JET'S PIZZA    Restaurant  Risk 2 (Medium)
# 336          336             JET'S PIZZA    Restaurant  Risk 2 (Medium)
# 341          341           BAMBOO GARDEN    Restaurant    Risk 1 (High)
# 342          342           BAMBOO GARDEN    Restaurant    Risk 1 (High)
# ...          ...                     ...           ...              ...
# 4672        4672          THAI THANK YOU    Restaurant    Risk 1 (High)
# 4723        4723               TACO BELL    Restaurant  Risk 2 (Medium)
# 4775        4775  STAN'S DONUTS & COFFEE    Restaurant  Risk 2 (Medium)
# 4776        4776  STAN'S DONUTS & COFFEE    Restaurant  Risk 2 (Medium)
# 4834        4834                  SUBWAY    Restaurant    Risk 1 (High)
#
#                   Address      Zip  Year          Inspection Type Results  \
# 139      3103 N CLARK ST   60657.0  2020                Complaint    Pass
# 335   2811 N ASHLAND AVE   60657.0  2021  Complaint Re-Inspection    Pass
# 336   2811 N ASHLAND AVE   60657.0  2021                Complaint    Fail
# 341      3203 N CLARK ST   60657.0  2021                  Canvass    Pass
# 342      3203 N CLARK ST   60657.0  2020                  Canvass    Pass
# ...                   ...      ...   ...                      ...     ...
# 4672  3248 N LINCOLN AVE   60657.0  2020                  Canvass    Pass
# 4723   920 W BELMONT AVE   60657.0  2020                Complaint    Pass
# 4775     3300 N BROADWAY   60657.0  2020    Canvass Re-Inspection    Pass
# 4776     3300 N BROADWAY   60657.0  2020                  Canvass    Fail
# 4834  2825 N ASHLAND AVE   60657.0  2020                  Canvass    Pass
#
#                                              Violations  ...  \
# 139   38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 335   47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 336   10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 341   39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 342   38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# ...                                                 ...  ...
# 4672  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4723  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 4775                                                NaN  ...
# 4776  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4834  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
#
#                                   display_address            address1  \
# 139      ['3103 N Clark St', 'Chicago, IL 60657']     3103 N Clark St
# 335   ['2811 N Ashland Ave', 'Chicago, IL 60657']  2811 N Ashland Ave
# 336   ['2811 N Ashland Ave', 'Chicago, IL 60657']  2811 N Ashland Ave
# 341      ['3203 N Clark St', 'Chicago, IL 60657']     3203 N Clark St
# 342      ['3203 N Clark St', 'Chicago, IL 60657']     3203 N Clark St
# ...                                           ...                 ...
# 4672  ['3248 N Lincoln Ave', 'Chicago, IL 60657']  3248 N Lincoln Ave
# 4723   ['920 W Belmont Ave', 'Chicago, IL 60657']   920 W Belmont Ave
# 4775     ['3300 N Broadway', 'Chicago, IL 60657']     3300 N Broadway
# 4776     ['3300 N Broadway', 'Chicago, IL 60657']     3300 N Broadway
# 4834  ['2825 N Ashland Ave', 'Chicago, IL 60657']  2825 N Ashland Ave
#
#       address2  address3     city   latitude  longitude zip code  \
# 139        NaN       NaN  Chicago  41.937978 -87.648880    60657
# 335        NaN       NaN  Chicago  41.933010 -87.668000    60657
# 336        NaN       NaN  Chicago  41.933010 -87.668000    60657
# 341        NaN       NaN  Chicago  41.940150 -87.650616    60657
# 342        NaN       NaN  Chicago  41.940150 -87.650616    60657
# ...        ...       ...      ...        ...        ...      ...
# 4672       NaN       NaN  Chicago  41.940920 -87.669770    60657
# 4723       NaN       NaN  Chicago  41.940112 -87.652541    60657
# 4775       NaN       NaN  Chicago  41.941969 -87.644614    60657
# 4776       NaN       NaN  Chicago  41.941969 -87.644614    60657
# 4834       NaN       NaN  Chicago  41.933205 -87.667806    60657
#
#                restaurant_id  price_integer
# 139   hwrBNgqg95B09sJpTqDUPg            1.0
# 335   6OU29ckrzBUV3Hx_IRwC6w            1.0
# 336   6OU29ckrzBUV3Hx_IRwC6w            1.0
# 341   AE_PCkL3_D6Q3vPdudb_vg            1.0
# 342   AE_PCkL3_D6Q3vPdudb_vg            1.0
# ...                      ...            ...
# 4672  JaQ91cEthG6G5oFJu8Y1jg            1.0
# 4723  3dckC8O3G6XZV1aFrcZLOA            1.0
# 4775  XGVGPeCGLoCewbgHI6m2Bw            1.0
# 4776  XGVGPeCGLoCewbgHI6m2Bw            1.0
# 4834  hFfMA1pDFaiSDIlQTQI1LA            1.0
#
# [65 rows x 32 columns]

# %%
yourself_13 = data.loc[data["Zip"] == 60613]
yourself_13 = yourself_13.loc[yourself_13["price_integer"] <2]
# yourself_13 = yourself_13.loc[yourself_13["Results"]== "Fail"]
yourself_13
# Out:
#       Unnamed: 0                  AKA Name Facility Type             Risk  \
# 966          966                    SUBWAY    Restaurant    Risk 1 (High)
# 967          967                    SUBWAY    Restaurant    Risk 1 (High)
# 968          968                    SUBWAY    Restaurant    Risk 1 (High)
# 969          969                    SUBWAY    Restaurant    Risk 1 (High)
# 970          970                    SUBWAY    Restaurant    Risk 1 (High)
# 971          971                    SUBWAY    Restaurant    Risk 1 (High)
# 972          972                    SUBWAY    Restaurant    Risk 1 (High)
# 973          973                    SUBWAY    Restaurant    Risk 1 (High)
# 974          974                    SUBWAY    Restaurant    Risk 1 (High)
# 1290        1290               ALWAYS THAI    Restaurant    Risk 1 (High)
# 1291        1291               ALWAYS THAI    Restaurant    Risk 1 (High)
# 1292        1292               ALWAYS THAI    Restaurant    Risk 1 (High)
# 1465        1465       HUNAN EGG ROLL KING    Restaurant    Risk 1 (High)
# 1466        1466       HUNAN EGG ROLL KING    Restaurant    Risk 1 (High)
# 1545        1545      TACO & BURRITO HOUSE    Restaurant    Risk 1 (High)
# 1546        1546      TACO & BURRITO HOUSE    Restaurant    Risk 1 (High)
# 1547        1547      TACO & BURRITO HOUSE    Restaurant    Risk 1 (High)
# 4421         1818 W MONTROSE AVE   60613.0  2021                  Canvass
# 4422         1818 W MONTROSE AVE   60613.0  2020    Canvass Re-Inspection
# 4423         1818 W MONTROSE AVE   60613.0  2020                  Canvass
# 4668           1851 W ADDISON ST   60613.0  2020                  Canvass
# 4694         1437 W MONTROSE AVE   60613.0  2020                  Canvass
# 4763            936 W ADDISON ST   60613.0  2020                  Canvass
# 4883       1323 W IRVING PARK RD   60613.0  2020                  Canvass
#
#      Results                                         Violations  ...  \
# 966     Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 967     Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 968     Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 969     Pass  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 970     Pass  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 971     Pass  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  ...
# 972     Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 973     Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 974     Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 1290    Pass  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 1291    Pass  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  ...
# 1292    Pass                                                NaN  ...
# 1465    Pass  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 1466    Pass  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 1545    Pass  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 1546    Pass  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 1547    Pass  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 1548    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 1549    Fail  5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  ...
# 2109    Fail  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 2110    Pass  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 2111    Fail  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  ...
# 2690    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2691    Pass  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  ...
# 2701    Pass  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  ...
# 2702    Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2703    Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2704    Pass  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 2705    Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2706    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2821    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 2822    Fail  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  ...
# 2823    Pass  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 2885    Pass                                                NaN  ...
# 2886    Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3179    Pass  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 3180    Fail  21. PROPER HOT HOLDING TEMPERATURES - Comments...  ...
# 3764    Pass  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3765    Pass  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 3807    Pass  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3808    Fail  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3935    Pass  41. WIPING CLOTHS: PROPERLY USED & STORED - Co...  ...
# 3936    Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 4223    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4224    Pass                                                NaN  ...
# 4225    Fail  25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCO...  ...
# 4242    Pass  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4243    Pass  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4326    Pass  56. ADEQUATE VENTILATION & LIGHTING; DESIGNATE...  ...
# 4327    Fail  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  ...
# 4421    Pass  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 4422    Pass                                                NaN  ...
# 4423    Fail  22. PROPER COLD HOLDING TEMPERATURES - Comment...  ...
# 4668    Pass  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
# 4694    Pass  45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPER...  ...
# 4763    Pass  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 4883    Pass  54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILI...  ...
#
#                                         display_address  \
# 966            ['3815 N Broadway', 'Chicago, IL 60613']
# 967         ['3952 N Sheridan Rd', 'Chicago, IL 60613']
# 968           ['951 W Addison St', 'Chicago, IL 60613']
# 969            ['3815 N Broadway', 'Chicago, IL 60613']
# 970         ['3952 N Sheridan Rd', 'Chicago, IL 60613']
# 971           ['951 W Addison St', 'Chicago, IL 60613']
# 972            ['3815 N Broadway', 'Chicago, IL 60613']
# 973         ['3952 N Sheridan Rd', 'Chicago, IL 60613']
# 974           ['951 W Addison St', 'Chicago, IL 60613']
# 1290     ['1825 W Irving Park Rd', 'Chicago, IL 60613']
# 1291     ['1825 W Irving Park Rd', 'Chicago, IL 60613']
# 1292     ['1825 W Irving Park Rd', 'Chicago, IL 60613']
# 1465            ['4204 N Bdwy St', 'Chicago, IL 60613']
# 1466            ['4204 N Bdwy St', 'Chicago, IL 60613']
# 1545           ['3939 N Broadway', 'Chicago, IL 60613']
# 1546           ['3939 N Broadway', 'Chicago, IL 60613']
# 1547           ['3939 N Broadway', 'Chicago, IL 60613']
# 1548           ['3939 N Broadway', 'Chicago, IL 60613']
# 1549           ['3939 N Broadway', 'Chicago, IL 60613']
# 2109         ['1027 W Addison St', 'Chicago, IL 60613']
# 2110         ['1027 W Addison St', 'Chicago, IL 60613']
# 2111         ['1027 W Addison St', 'Chicago, IL 60613']
# 2690        ['3720 N Lincoln Ave', 'Chicago, IL 60613']
# 2691        ['3720 N Lincoln Ave', 'Chicago, IL 60613']
# 2701        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2702        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2703        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2704        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2705        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2706        ['3932 N Broadway St', 'Chicago, IL 60613']
# 2821           ['3716 N Clark St', 'Chicago, IL 60613']
# 2822           ['3716 N Clark St', 'Chicago, IL 60613']
# 2823           ['3716 N Clark St', 'Chicago, IL 60613']
# 2885           ['3610 N Clark St', 'Chicago, IL 60613']
# 2886           ['3610 N Clark St', 'Chicago, IL 60613']
# 3179      ['3706 N Southport Ave', 'Chicago, IL 60613']
# 3180      ['3706 N Southport Ave', 'Chicago, IL 60613']
# 3764           ['3731 N Clark St', 'Chicago, IL 60613']
# 3765           ['3731 N Clark St', 'Chicago, IL 60613']
# 3807  ['1612 W Irving Park Rd', 'The Long Room', 'Ch...
# 3808  ['1612 W Irving Park Rd', 'The Long Room', 'Ch...
# 3935     ['1635 W Irving Park Rd', 'Chicago, IL 60613']
# 3936     ['1635 W Irving Park Rd', 'Chicago, IL 60613']
# 4223    ['1821A W Irving Park Rd', 'Chicago, IL 60613']
# 4224    ['1821A W Irving Park Rd', 'Chicago, IL 60613']
# 4225    ['1821A W Irving Park Rd', 'Chicago, IL 60613']
# 4242        ['3925 N Lincoln Ave', 'Chicago, IL 60613']
# 4243        ['3925 N Lincoln Ave', 'Chicago, IL 60613']
# 4326     ['1814 W Irving Park Rd', 'Chicago, IL 60613']
# 4327     ['1814 W Irving Park Rd', 'Chicago, IL 60613']
# 4421  ['1818 W Montrose & Brown Line L', 'Chicago, I...
# 4422  ['1818 W Montrose & Brown Line L', 'Chicago, I...
# 4423  ['1818 W Montrose & Brown Line L', 'Chicago, I...
# 4668         ['1851 W Addison St', 'Chicago, IL 60613']
# 4694       ['1437 W Montrose Ave', 'Chicago, IL 60613']
# 4763          ['936 W Addison St', 'Chicago, IL 60613']
# 4883     ['1323 W Irving Park Rd', 'Chicago, IL 60613']
#
#                             address1  address2       address3     city  \
# 966                  3815 N Broadway       NaN            NaN  Chicago
# 967               3952 N Sheridan Rd       NaN            NaN  Chicago
# 968                 951 W Addison St       NaN            NaN  Chicago
# 969                  3815 N Broadway       NaN            NaN  Chicago
# 970               3952 N Sheridan Rd       NaN            NaN  Chicago
# 971                 951 W Addison St       NaN            NaN  Chicago
# 972                  3815 N Broadway       NaN            NaN  Chicago
# 973               3952 N Sheridan Rd       NaN            NaN  Chicago
# 974                 951 W Addison St       NaN            NaN  Chicago
# 1290           1825 W Irving Park Rd       NaN            NaN  Chicago
# 1291           1825 W Irving Park Rd       NaN            NaN  Chicago
# 1292           1825 W Irving Park Rd       NaN            NaN  Chicago
# 1465                  4204 N Bdwy St       NaN            NaN  Chicago
# 1466                  4204 N Bdwy St       NaN            NaN  Chicago
# 1545                 3939 N Broadway       NaN            NaN  Chicago
# 1546                 3939 N Broadway       NaN            NaN  Chicago
# 1547                 3939 N Broadway       NaN            NaN  Chicago
# 1548                 3939 N Broadway       NaN            NaN  Chicago
# 1549                 3939 N Broadway       NaN            NaN  Chicago
# 2109               1027 W Addison St       NaN            NaN  Chicago
# 2110               1027 W Addison St       NaN            NaN  Chicago
# 2111               1027 W Addison St       NaN            NaN  Chicago
# 2690              3720 N Lincoln Ave       NaN            NaN  Chicago
# 2691              3720 N Lincoln Ave       NaN            NaN  Chicago
# 2701              3932 N Broadway St       NaN            NaN  Chicago
# 2702              3932 N Broadway St       NaN            NaN  Chicago
# 2703              3932 N Broadway St       NaN            NaN  Chicago
# 2704              3932 N Broadway St       NaN            NaN  Chicago
# 2705              3932 N Broadway St       NaN            NaN  Chicago
# 2706              3932 N Broadway St       NaN            NaN  Chicago
# 2821                 3716 N Clark St       NaN            NaN  Chicago
# 2822                 3716 N Clark St       NaN            NaN  Chicago
# 2823                 3716 N Clark St       NaN            NaN  Chicago
# 2885                 3610 N Clark St       NaN            NaN  Chicago
# 2886                 3610 N Clark St       NaN            NaN  Chicago
# 3179            3706 N Southport Ave       NaN            NaN  Chicago
# 3180            3706 N Southport Ave       NaN            NaN  Chicago
# 3764                 3731 N Clark St       NaN            NaN  Chicago
# 3765                 3731 N Clark St       NaN            NaN  Chicago
# 3807           1612 W Irving Park Rd       NaN  The Long Room  Chicago
# 3808           1612 W Irving Park Rd       NaN  The Long Room  Chicago
# 3935           1635 W Irving Park Rd       NaN            NaN  Chicago
# 3936           1635 W Irving Park Rd       NaN            NaN  Chicago
# 4223          1821A W Irving Park Rd       NaN            NaN  Chicago
# 4224          1821A W Irving Park Rd       NaN            NaN  Chicago
# 4225          1821A W Irving Park Rd       NaN            NaN  Chicago
# 4242              3925 N Lincoln Ave       NaN            NaN  Chicago
# 4243              3925 N Lincoln Ave       NaN            NaN  Chicago
# 4326           1814 W Irving Park Rd       NaN            NaN  Chicago
# 4327           1814 W Irving Park Rd       NaN            NaN  Chicago
# 4421  1818 W Montrose & Brown Line L       NaN            NaN  Chicago
# 4422  1818 W Montrose & Brown Line L       NaN            NaN  Chicago
# 4423  1818 W Montrose & Brown Line L       NaN            NaN  Chicago
# 4668               1851 W Addison St       NaN            NaN  Chicago
# 4694             1437 W Montrose Ave       NaN            NaN  Chicago
# 4763                936 W Addison St       NaN            NaN  Chicago
# 2702   3932 N BROADWAY   60613.0  2021  Canvass Re-Inspection    Fail
# 2703   3932 N BROADWAY   60613.0  2021                Canvass    Fail
# 2704   3932 N BROADWAY   60613.0  2020              Complaint    Pass
# 2705   3932 N BROADWAY   60613.0  2020                Canvass    Fail
# 2706   3932 N BROADWAY   60613.0  2020  Canvass Re-Inspection    Pass
# 4763  936 W ADDISON ST   60613.0  2020                Canvass    Pass
#
#                                              Violations  ...  \
# 2701  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  ...
# 2702  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2703  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2704  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 2705  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 2706  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4763  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
#
#                                   display_address            address1  \
# 2701  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 2702  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 2703  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 2704  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 2705  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 2706  ['3932 N Broadway St', 'Chicago, IL 60613']  3932 N Broadway St
# 4763    ['936 W Addison St', 'Chicago, IL 60613']    936 W Addison St
#
#       address2  address3     city   latitude  longitude zip code  \
# 2701       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 2702       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 2703       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 2704       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 2705       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 2706       NaN       NaN  Chicago  41.953508 -87.650004    60613
# 4763       NaN       NaN  Chicago  41.947385 -87.653345    60613
#
#                restaurant_id  price_integer
# 2701  CuR6GZEeh0TaD9KVd5837g            1.0
# 2702  CuR6GZEeh0TaD9KVd5837g            1.0
# 2703  CuR6GZEeh0TaD9KVd5837g            1.0
# 2704  CuR6GZEeh0TaD9KVd5837g            1.0
# 2705  CuR6GZEeh0TaD9KVd5837g            1.0
# 2706  CuR6GZEeh0TaD9KVd5837g            1.0
# 4763  c72MBSsS0xs5SWk8TX6eoQ            1.0
#
# [7 rows x 32 columns]

# %%
spots = ["TACO BELL"]
yourself_mark2 = yourself.loc[yourself["AKA Name"].isin(spots),:]
yourself_mark2
# Out:
#       Unnamed: 0   AKA Name Facility Type             Risk  \
# 4723        4723  TACO BELL    Restaurant  Risk 2 (Medium)
#
#                  Address      Zip  Year Inspection Type Results  \
# 4723  920 W BELMONT AVE   60657.0  2020       Complaint    Pass
#
#                                              Violations  ...  \
# 4723  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
#
#                                  display_address           address1  address2  \
# 4723  ['920 W Belmont Ave', 'Chicago, IL 60657']  920 W Belmont Ave       NaN
#
#       address3     city   latitude  longitude zip code  \
# 4723       NaN  Chicago  41.940112 -87.652541    60657
#
#                restaurant_id  price_integer
# 4723  3dckC8O3G6XZV1aFrcZLOA            1.0
#
# [1 rows x 32 columns]

# %%
urs_60613 = yourself[["latitude", "longitude"]]
urs_60657 = yourself_13[["latitude", "longitude"]]
urs_marker = yourself_mark[["latitude", "longitude"]]
urs_marker2 = yourself_mark2[["latitude", "longitude"]]
fig = gmaps.figure()
urs60613_symbols = gmaps.symbol_layer(urs_60613, fill_color="blue", stroke_color = "blue")
fig.add_layer(urs60613_symbols)
urs60657_symbols = gmaps.symbol_layer(urs_60657, fill_color="red", stroke_color = "red")
fig.add_layer(urs60657_symbols)
urs_marker_1 = gmaps.marker_layer(urs_marker)
fig.add_layer(urs_marker_1)
urs_marker_2 = gmaps.marker_layer(urs_marker2)
fig.add_layer(urs_marker_2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#potential date
date = data.loc[data["rating"] >3]
date = date.loc[date["Zip"] == 60657]
date = date.loc[date["Results"] == "Pass"]
date = date.loc[date["price_integer"] >= 3]
date
# Out:
#       Unnamed: 0       AKA Name Facility Type           Risk  \
# 2651        2651  DEAR MARGARET    Restaurant   Risk 3 (Low)
# 2652        2652  DEAR MARGARET    Restaurant  Risk 1 (High)
# 2653        2653  DEAR MARGARET    Restaurant  Risk 1 (High)
#
#                   Address      Zip  Year        Inspection Type Results  \
# 2651  2965 N LINCOLN AVE   60657.0  2021  License Re-Inspection    Pass
# 2652  2965 N LINCOLN AVE   60657.0  2021                Canvass    Pass
# 2653  2965 N LINCOLN AVE   60657.0  2020                License    Pass
#
#                                              Violations  ...  \
# 2651                                                NaN  ...
# 2652  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  ...
# 2653  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  ...
#
#                                   display_address            address1  \
# 2651  ['2965 N Lincoln Ave', 'Chicago, IL 60657']  2965 N Lincoln Ave
# 2652  ['2965 N Lincoln Ave', 'Chicago, IL 60657']  2965 N Lincoln Ave
# 2653  ['2965 N Lincoln Ave', 'Chicago, IL 60657']  2965 N Lincoln Ave
#
#       address2  address3     city  latitude longitude zip code  \
# 2651       NaN       NaN  Chicago  41.93589 -87.66294    60657
# 2652       NaN       NaN  Chicago  41.93589 -87.66294    60657
# 2653       NaN       NaN  Chicago  41.93589 -87.66294    60657
#
#                restaurant_id  price_integer
# 2651  -otD9myzwCgSYXdcx90jLQ            3.0
# 2652  -otD9myzwCgSYXdcx90jLQ            3.0
# 2653  -otD9myzwCgSYXdcx90jLQ            3.0
#
# [3 rows x 32 columns]

# %%
date_13 = data.loc[data["rating"] > 3]
date_13 = date_13.loc[date_13["Zip"] == 60613]
date_13 = date_13.loc[date_13["Results"] == "Pass"]
date_13 = date_13.loc[date_13["price_integer"] >= 3]
date_13
# Out:
#       Unnamed: 0   AKA Name Facility Type           Risk  \
# 2251        2251  TANGO SUR    Restaurant  Risk 1 (High)
# 2252        2252  TANGO SUR    Restaurant  Risk 1 (High)
#
#                            Address      Zip  Year Inspection Type Results  \
# 2251  3761 - 3763 N SOUTHPORT AVE   60613.0  2021         Canvass    Pass
# 2252  3761 - 3763 N SOUTHPORT AVE   60613.0  2020         Canvass    Pass
#
#                                              Violations  ...  \
# 2251  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 2252  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
#
#                                     display_address              address1  \
# 2251  ['3763 N Southport Ave', 'Chicago, IL 60613']  3763 N Southport Ave
# 2252  ['3763 N Southport Ave', 'Chicago, IL 60613']  3763 N Southport Ave
#
#       address2  address3     city   latitude  longitude zip code  \
# 2251       NaN       NaN  Chicago  41.950784 -87.663903    60613
# 2252       NaN       NaN  Chicago  41.950784 -87.663903    60613
#
#                restaurant_id  price_integer
# 2251  uyUKtGWLYgu-RLjlNImy0A            3.0
# 2252  uyUKtGWLYgu-RLjlNImy0A            3.0
#
# [2 rows x 32 columns]

# %%
date_60613 = date_13[["latitude", "longitude"]]
date_60657 = date[["latitude", "longitude"]]
fig = gmaps.figure()
date60613_symbols = gmaps.symbol_layer(date_60613, fill_color="blue", stroke_color = "blue")
fig.add_layer(date60613_symbols)
date60657_symbols = gmaps.symbol_layer(date_60657, fill_color="red", stroke_color = "red")
fig.add_layer(date60657_symbols)
marker_1 = gmaps.marker_layer(date_60613)
fig.add_layer(marker_1)
marker_2 = gmaps.marker_layer(date_60657)
fig.add_layer(marker_2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#dinner downtown and all restaurants must have passed an inspection
zips = [60661, 60654, 60601, 60606, 60661, 60607, 60602]
downtown = data.loc[data["Results"]== "Pass"]
#Lets just grab food
zip_downtown = downtown.loc[downtown["Zip"].isin(zips),:]
#  & (downtown["Zip"]==60654)]                        
food_downtown = zip_downtown.loc[zip_downtown["price_integer"] <= 2]
food_downtown["category"].value_counts()
# Out:
# sandwiches          161
# mexican              46
# salad                25
# hotdogs              22
# mediterranean        17
# coffee               16
# burgers              16
# newamerican          14
# pizza                12
# italian              11
# breakfast_brunch     10
# bbq                  10
# diners               10
# tradamerican          9
# chinese               9
# sushi                 7
# vegetarian            6
# vegan                 6
# cafes                 5
# cocktailbars          5
# delis                 5
# buffets               5
# noodles               4
# vietnamese            4
# donuts                4
# hotdog                4
# korean                4
# bagels                4
# pubs                  4
# greek                 4
# thai                  4
# japanese              3
# mideastern            3
# sportsbars            3
# halal                 3
# bakeries              3
# chicken_wings         3
# seafood               3
# chickenshop           2
# danceclubs            2
# portuguese            2
# cuban                 2
# cajun                 2
# lounges               2
# indpak                2
# irish                 2
# beerbar               2
# falafel               2
# juicebars             2
# cheesesteaks          1
# butcher               1
# pancakes              1
# whiskeybars           1
# tapasmallplates       1
# ramen                 1
# bars                  1
# asianfusion           1
# southern              1
# panasian              1
# Name: category, dtype: int64

# %%
#create dataframes for sandiwches, mexican, and salads
sand_downtown = food_downtown.loc[food_downtown["category"] == "sandwiches"]
mex_downtown = food_downtown.loc[food_downtown["category"] == "mexican"]
sal_downtown = food_downtown.loc[food_downtown["category"] == "salad"]
sal_downtown
# Out:
#       Unnamed: 0        AKA Name Facility Type           Risk  \
# 180          180         FRESHII    Restaurant  Risk 1 (High)
# 182          182         FRESHII    Restaurant  Risk 1 (High)
# 184          184         FRESHII    Restaurant  Risk 1 (High)
# 186          186         FRESHII    Restaurant  Risk 1 (High)
# 192          192         FRESHII    Restaurant  Risk 1 (High)
# 194          194         FRESHII    Restaurant  Risk 1 (High)
# 3018        3018    MIXED GREENS    Restaurant  Risk 1 (High)
# 3019        3019    MIXED GREENS    Restaurant  Risk 1 (High)
# 3020        3020    MIXED GREENS    Restaurant  Risk 1 (High)
# 3021        3021    MIXED GREENS    Restaurant  Risk 1 (High)
# 3022        3022    MIXED GREENS    Restaurant  Risk 1 (High)
47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3694  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3695                                                NaN  ...
# 3815                                                NaN  ...
# 4164  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 4349  58. ALLERGEN TRAINING AS REQUIRED - Comments: ...  ...
# 4350  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  ...
# 4404  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 4405  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                         display_address  \
# 180             ['17 E Monroe St', 'Chicago, IL 60606']
# 182         ['111 W Jackson Blvd', 'Chicago, IL 60604']
# 184             ['17 E Monroe St', 'Chicago, IL 60606']
# 186         ['111 W Jackson Blvd', 'Chicago, IL 60604']
# 192             ['17 E Monroe St', 'Chicago, IL 60606']
# 194         ['111 W Jackson Blvd', 'Chicago, IL 60604']
# 3018         ['175 N Franklin St', 'Chicago, IL 60606']
# 3019             ['308 W Erie St', 'Chicago, IL 60654']
# 3020         ['175 N Franklin St', 'Chicago, IL 60606']
# 3021             ['308 W Erie St', 'Chicago, IL 60654']
# 3022         ['175 N Franklin St', 'Chicago, IL 60606']
# 3023             ['308 W Erie St', 'Chicago, IL 60654']
# 3024         ['175 N Franklin St', 'Chicago, IL 60606']
# 3025             ['308 W Erie St', 'Chicago, IL 60654']
# 3026         ['175 N Franklin St', 'Chicago, IL 60606']
# 3027             ['308 W Erie St', 'Chicago, IL 60654']
# 3693            ['623 N State St', 'Chicago, IL 60654']
# 3694            ['623 N State St', 'Chicago, IL 60654']
# 3695            ['623 N State St', 'Chicago, IL 60654']
# 3815  ['520 N Michigan Ave', 'Fl 4', 'Chicago, IL 60...
# 4164          ['1000 Randolph St', 'Chicago, IL 60607']
# 4349  ['155 N Upper Wacker Dr', 'Ste 102', 'Chicago,...
# 4350  ['155 N Upper Wacker Dr', 'Ste 102', 'Chicago,...
# 4404        ['350 N LaSalle Blvd', 'Chicago, IL 60606']
# 4405        ['350 N LaSalle Blvd', 'Chicago, IL 60606']
#
#                    address1  address2  address3     city   latitude  \
# 180          17 E Monroe St       NaN       NaN  Chicago  41.880295
# 182      111 W Jackson Blvd       NaN       NaN  Chicago  41.877999
# 184          17 E Monroe St       NaN       NaN  Chicago  41.880295
# 186      111 W Jackson Blvd       NaN       NaN  Chicago  41.877999
# 192          17 E Monroe St       NaN       NaN  Chicago  41.880295
# 194      111 W Jackson Blvd       NaN       NaN  Chicago  41.877999
# 3018      175 N Franklin St       NaN       NaN  Chicago  41.885410
# 3019          308 W Erie St       NaN       NaN  Chicago  41.894200
# 3020      175 N Franklin St       NaN       NaN  Chicago  41.885410
# 3021          308 W Erie St       NaN       NaN  Chicago  41.894200
# 3022      175 N Franklin St       NaN       NaN  Chicago  41.885410
# 3023          308 W Erie St       NaN       NaN  Chicago  41.894200
# 3024      175 N Franklin St       NaN       NaN  Chicago  41.885410
# 3025          308 W Erie St       NaN       NaN  Chicago  41.894200
# 3026      175 N Franklin St       NaN       NaN  Chicago  41.885410
# 3027          308 W Erie St       NaN       NaN  Chicago  41.894200
# 3693         623 N State St       NaN       NaN  Chicago  41.893103
# 3694         623 N State St       NaN       NaN  Chicago  41.893103
# 3695         623 N State St       NaN       NaN  Chicago  41.893103
# 3815     520 N Michigan Ave      Fl 4       NaN  Chicago  41.891502
# 4164       1000 Randolph St       NaN       NaN  Chicago  41.884614
# 4349  155 N Upper Wacker Dr   Ste 102       NaN  Chicago  41.884801
# 4350  155 N Upper Wacker Dr   Ste 102       NaN  Chicago  41.884801
# 4404     350 N LaSalle Blvd       NaN       NaN  Chicago  41.888886
# 4405     350 N LaSalle Blvd       NaN       NaN  Chicago  41.888886
#
#       longitude zip code           restaurant_id  price_integer
# 180  -87.627220    60606  mPpnVe0bWPYrAnlDsQulAQ            1.0
# 182  -87.631331    60604  zNKDS43sOrWMainVltqvRQ            2.0
# 184  -87.627220    60606  mPpnVe0bWPYrAnlDsQulAQ            1.0
# 186  -87.631331    60604  zNKDS43sOrWMainVltqvRQ            2.0
# 192  -87.627220    60606  mPpnVe0bWPYrAnlDsQulAQ            1.0
# 194  -87.631331    60604  zNKDS43sOrWMainVltqvRQ            2.0
# 3018 -87.635215    60606  5UvsmAKCasjiHSN7ZFbi6g            1.0
# 3019 -87.636200    60654  Ys_t7qV1RrjYTlUlxyyWWQ            2.0
# 3020 -87.635215    60606  5UvsmAKCasjiHSN7ZFbi6g            1.0
# 3021 -87.636200    60654  Ys_t7qV1RrjYTlUlxyyWWQ            2.0
# 3022 -87.635215    60606  5UvsmAKCasjiHSN7ZFbi6g            1.0
# 3023 -87.636200    60654  Ys_t7qV1RrjYTlUlxyyWWQ            2.0
# 3024 -87.635215    60606  5UvsmAKCasjiHSN7ZFbi6g            1.0
# 3025 -87.636200    60654  Ys_t7qV1RrjYTlUlxyyWWQ            2.0
# 3026 -87.635215    60606  5UvsmAKCasjiHSN7ZFbi6g            1.0
# 3027 -87.636200    60654  Ys_t7qV1RrjYTlUlxyyWWQ            2.0
# 3693 -87.627898    60654  c1J0cIfrq8zC-zovH5AJRQ            2.0
# 3694 -87.627898    60654  c1J0cIfrq8zC-zovH5AJRQ            2.0
# 3695 -87.627898    60654  c1J0cIfrq8zC-zovH5AJRQ            2.0
# 3815 -87.624544    60611  7FNu-uITDfg-IdCEfF239A            1.0
# 4164 -87.652346    60607  4kmJ2mTGWxhDjt7PLVS92g            2.0
# 4349 -87.636330    60606  mopPEMAzUadJgKZS-gDI9A            2.0
# 4350 -87.636330    60606  mopPEMAzUadJgKZS-gDI9A            2.0
# 4404 -87.632867    60606  nszHW0BwtmBpSMlJitnKJg            2.0
# 4405 -87.632867    60606  nszHW0BwtmBpSMlJitnKJg            2.0
#
# [25 rows x 32 columns]

# %%
#create specific df with restauarants to create markers
place = ["108 N STATE ST "]
sand_downtown_mark = sand_downtown.loc[sand_downtown["Address"].isin(place),:]
sand_downtown_mark
# Out:
#       Unnamed: 0    AKA Name Facility Type           Risk          Address  \
# 4115        4115  WHICH WICH    Restaurant  Risk 1 (High)  108 N STATE ST
# 4116        4116  WHICH WICH    Restaurant  Risk 1 (High)  108 N STATE ST
#
#           Zip  Year        Inspection Type Results  \
# 4115  60602.0  2021                Canvass    Pass
# 4116  60602.0  2020  Canvass Re-Inspection    Pass
#
#                                              Violations  ...  \
# 4115  56. ADEQUATE VENTILATION & LIGHTING; DESIGNATE...  ...
# 4116  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  ...
#
#                                         display_address        address1  \
# 4115  ['108 N State St', 'Ste 002', 'Chicago, IL 606...  108 N State St
# 4116  ['108 N State St', 'Ste 002', 'Chicago, IL 606...  108 N State St
#
#       address2  address3     city   latitude  longitude zip code  \
# 4115   Ste 002       NaN  Chicago  41.883599 -87.628298    60602
# 4116   Ste 002       NaN  Chicago  41.883599 -87.628298    60602
#
#                restaurant_id  price_integer
# 4115  5WU5wPtC9DpgwWqkQurAnw            1.0
# 4116  5WU5wPtC9DpgwWqkQurAnw            1.0
#
# [2 rows x 32 columns]

# %%
#create a mex marker
place = ["235 W LAKE ST "]
mex_downtown_mark = mex_downtown.loc[mex_downtown["Address"].isin(place),:]
mex_downtown_mark
# Out:
#       Unnamed: 0                AKA Name Facility Type           Risk  \
# 4408        4408  CHIPOTLE MEXICAN GRILL    Restaurant  Risk 1 (High)
# 4409        4409  CHIPOTLE MEXICAN GRILL    Restaurant  Risk 1 (High)
#
#              Address      Zip  Year Inspection Type Results Violations  ...  \
# 4408  235 W LAKE ST   60606.0  2021         Canvass    Pass        NaN  ...
# 4409  235 W LAKE ST   60606.0  2020         Canvass    Pass        NaN  ...
#
#                              display_address       address1  address2  \
# 4408  ['233 W Lake St', 'Chicago, IL 60606']  233 W Lake St       NaN
# 4409  ['233 W Lake St', 'Chicago, IL 60606']  233 W Lake St       NaN
#
#       address3     city   latitude  longitude zip code  \
# 4408       NaN  Chicago  41.885538 -87.635217    60606
# 4409       NaN  Chicago  41.885538 -87.635217    60606
#
#                restaurant_id  price_integer
# 4408  oWpGUnJk-W3xHNekCZ2v6A            1.0
# 4409  oWpGUnJk-W3xHNekCZ2v6A            1.0
#
# [2 rows x 32 columns]

# %%
#create a salad place
place = ["350 N LA SALLE DR "]
sal_downtown_mark = sal_downtown.loc[sal_downtown["Address"].isin(place),:]
sal_downtown_mark
# Out:
#       Unnamed: 0 AKA Name Facility Type           Risk             Address  \
# 4404        4404  FRESHII    Restaurant  Risk 1 (High)  350 N LA SALLE DR
# 4405        4405  FRESHII    Restaurant  Risk 1 (High)  350 N LA SALLE DR
#
#           Zip  Year Inspection Type Results  \
# 4404  60654.0  2021         Canvass    Pass
# 4405  60654.0  2020         Canvass    Pass
#
#                                              Violations  ...  \
# 4404  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  ...
# 4405  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                   display_address            address1  \
# 4404  ['350 N LaSalle Blvd', 'Chicago, IL 60606']  350 N LaSalle Blvd
# 4405  ['350 N LaSalle Blvd', 'Chicago, IL 60606']  350 N LaSalle Blvd
#
#       address2  address3     city   latitude  longitude zip code  \
# 4404       NaN       NaN  Chicago  41.888886 -87.632867    60606
# 4405       NaN       NaN  Chicago  41.888886 -87.632867    60606
#
#                restaurant_id  price_integer
# 4404  nszHW0BwtmBpSMlJitnKJg            2.0
# 4405  nszHW0BwtmBpSMlJitnKJg            2.0
#
# [2 rows x 32 columns]

# %%
sand_din = sand_downtown[["latitude", "longitude"]]
mex_din = mex_downtown[["latitude", "longitude"]]
sal_din = sal_downtown[["latitude", "longitude"]]
sand_mark = sand_downtown_mark[["latitude", "longitude"]]
mex_mark = mex_downtown_mark[["latitude", "longitude"]]
sal_mark = sal_downtown_mark[["latitude", "longitude"]]
fig = gmaps.figure()
sand_symbols = gmaps.symbol_layer(sand_din, fill_color="blue", stroke_color = "blue")
fig.add_layer(sand_symbols)
mex_symbols = gmaps.symbol_layer(mex_din, fill_color="red", stroke_color = "red")
fig.add_layer(mex_symbols)
sal_symbols = gmaps.symbol_layer(sal_din, fill_color="green", stroke_color = "green")
fig.add_layer(sal_symbols)
sand_mark_1 = gmaps.marker_layer(sand_mark)
fig.add_layer(sand_mark_1)
mex_mark_1 = gmaps.marker_layer(mex_mark)
fig.add_layer(mex_mark_1)
sal_mark_1 = gmaps.marker_layer(sal_mark)
fig.add_layer(sal_mark_1)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#fancy downtown restaurants
fancy_downtown = zip_downtown.loc[zip_downtown["price_integer"] == 4]
fancy_downtown
# Out:
#       Unnamed: 0                AKA Name Facility Type           Risk  \
# 2063        2063         TEATRO ZINZANNI    Restaurant  Risk 1 (High)
# 3290        3290      PRIME & PROVISIONS    Restaurant  Risk 1 (High)
# 3291        3291      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3292        3292      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3293        3293      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3508        3508  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 3509        3509  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 3510        3510  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 4549        4549                   SEPIA    Restaurant  Risk 1 (High)
# 4552        4552                 ROISTER    Restaurant  Risk 1 (High)
# 4565        4565     MASTRO'S STEAKHOUSE    Restaurant  Risk 1 (High)
# 4725        4725               RPM STEAK    Restaurant  Risk 1 (High)
#
#                    Address      Zip  Year Inspection Type Results  \
# 2063     32 W RANDOLPH ST   60601.0  2021         Canvass    Pass
# 3290    222 N LA SALLE ST   60601.0  2021         License    Pass
# 3291    222 N LA SALLE ST   60601.0  2021         License    Pass
# 3292    222 N LA SALLE ST   60601.0  2021         License    Pass
# 3293    222 N LA SALLE ST   60601.0  2021         License    Pass
# 3508    300 N LA SALLE ST   60654.0  2021       Complaint    Pass
# 3509    300 N LA SALLE ST   60654.0  2020       Complaint    Pass
# 3510    300 N LA SALLE ST   60654.0  2020         Canvass    Pass
# 4549   123 N JEFFERSON ST   60661.0  2020         Canvass    Pass
# 4552  951 W FULTON MARKET   60607.0  2020       Complaint    Pass
# 4565    520 N DEARBORN ST   60654.0  2020         Canvass    Pass
# 4725       66 W KINZIE ST   60654.0  2020         Canvass    Pass
#
#                                              Violations  ...  \
# 2063  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 3290  44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STO...  ...
# 3291                                                NaN  ...
# 3292                                                NaN  ...
# 3293                                                NaN  ...
# 3508  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3509  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3510  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4549  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
# 4552  56. ADEQUATE VENTILATION & LIGHTING; DESIGNATE...  ...
# 4565  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 4725  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                    display_address             address1  \
# 2063     ['32 W Randolph St', 'Chicago, IL 60601']     32 W Randolph St
# 3290    ['222 N La Salle St', 'Chicago, IL 60601']    222 N La Salle St
# 3291    ['222 N La Salle St', 'Chicago, IL 60601']    222 N La Salle St
# 3292    ['222 N La Salle St', 'Chicago, IL 60601']    222 N La Salle St
# 3293    ['222 N La Salle St', 'Chicago, IL 60601']    222 N La Salle St
# 3508        ['300 N Lasalle', 'Chicago, IL 60654']        300 N Lasalle
# 3509        ['300 N Lasalle', 'Chicago, IL 60654']        300 N Lasalle
# 3510        ['300 N Lasalle', 'Chicago, IL 60654']        300 N Lasalle
# 4549   ['123 N Jefferson St', 'Chicago, IL 60661']   123 N Jefferson St
# 4552  ['951 W Fulton Market', 'Chicago, IL 60607']  951 W Fulton Market
# 4565    ['520 N Dearborn St', 'Chicago, IL 60654']    520 N Dearborn St
# 4725       ['66 W Kinzie St', 'Chicago, IL 60654']       66 W Kinzie St
#
#       address2  address3     city   latitude  longitude zip code  \
# 2063       NaN       NaN  Chicago  41.884624 -87.628928    60601
# 3290       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3291       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3292       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3293       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3508       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 3509       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 3510       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 4549       NaN       NaN  Chicago  41.883933 -87.642400    60661
# 4552       NaN       NaN  Chicago  41.886524 -87.651866    60607
# 4565       NaN       NaN  Chicago  41.891523 -87.629849    60654
# 4725       NaN       NaN  Chicago  41.889322 -87.630610    60654
#
#                restaurant_id  price_integer
# 2063  LEzGovGCIDkABHej3KvMwA            4.0
# 3290  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3291  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3292  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3293  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3508  olT3-oFfj5jCuv49M6gZgQ            4.0
# 3509  olT3-oFfj5jCuv49M6gZgQ            4.0
# 3510  olT3-oFfj5jCuv49M6gZgQ            4.0
# 4549  mPFMi734NXkvLFotygLrCA            4.0
# 4552  xF8ZBzcMGpBd6U5GAbb-hQ            4.0
# 4565  Pcg4FtfbvSMMwrYuE1yVjQ            4.0
# 4725  JMWtBuuNmTXqoBs06Wt_7w            4.0
#
# [12 rows x 32 columns]

# %%
#fancy restaurants marker
spots = ["CHICAGO CUT STEAKHOUSE", "PRIME & PROVISIONS", "SEPIA" ]
fancy_downtown_mark = fancy_downtown.loc[fancy_downtown["AKA Name"].isin(spots),:]
fancy_downtown_mark
# Out:
#       Unnamed: 0                AKA Name Facility Type           Risk  \
# 3290        3290      PRIME & PROVISIONS    Restaurant  Risk 1 (High)
# 3291        3291      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3292        3292      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3293        3293      PRIME & PROVISIONS    Restaurant   Risk 3 (Low)
# 3508        3508  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 3509        3509  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 3510        3510  CHICAGO CUT STEAKHOUSE    Restaurant  Risk 1 (High)
# 4549        4549                   SEPIA    Restaurant  Risk 1 (High)
#
#                   Address      Zip  Year Inspection Type Results  \
# 3290   222 N LA SALLE ST   60601.0  2021         License    Pass
# 3291   222 N LA SALLE ST   60601.0  2021         License    Pass
# 3292   222 N LA SALLE ST   60601.0  2021         License    Pass
# 3293   222 N LA SALLE ST   60601.0  2021         License    Pass
# 3508   300 N LA SALLE ST   60654.0  2021       Complaint    Pass
# 3509   300 N LA SALLE ST   60654.0  2020       Complaint    Pass
# 3510   300 N LA SALLE ST   60654.0  2020         Canvass    Pass
# 4549  123 N JEFFERSON ST   60661.0  2020         Canvass    Pass
#
#                                              Violations  ...  \
# 3290  44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STO...  ...
# 3291                                                NaN  ...
# 3292                                                NaN  ...
# 3293                                                NaN  ...
# 3508  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3509  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  ...
# 3510  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  ...
# 4549  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  ...
#
#                                   display_address            address1  \
# 3290   ['222 N La Salle St', 'Chicago, IL 60601']   222 N La Salle St
# 3291   ['222 N La Salle St', 'Chicago, IL 60601']   222 N La Salle St
# 3292   ['222 N La Salle St', 'Chicago, IL 60601']   222 N La Salle St
# 3293   ['222 N La Salle St', 'Chicago, IL 60601']   222 N La Salle St
# 3508       ['300 N Lasalle', 'Chicago, IL 60654']       300 N Lasalle
# 3509       ['300 N Lasalle', 'Chicago, IL 60654']       300 N Lasalle
# 3510       ['300 N Lasalle', 'Chicago, IL 60654']       300 N Lasalle
# 4549  ['123 N Jefferson St', 'Chicago, IL 60661']  123 N Jefferson St
#
#       address2  address3     city   latitude  longitude zip code  \
# 3290       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3291       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3292       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3293       NaN       NaN  Chicago  41.886497 -87.633559    60601
# 3508       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 3509       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 3510       NaN       NaN  Chicago  41.887972 -87.633348    60654
# 4549       NaN       NaN  Chicago  41.883933 -87.642400    60661
#
#                restaurant_id  price_integer
# 3290  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3291  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3292  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3293  3Q_N0K28SRJbPy2sz0QqVw            4.0
# 3508  olT3-oFfj5jCuv49M6gZgQ            4.0
# 3509  olT3-oFfj5jCuv49M6gZgQ            4.0
# 3510  olT3-oFfj5jCuv49M6gZgQ            4.0
# 4549  mPFMi734NXkvLFotygLrCA            4.0
#
# [8 rows x 32 columns]

# %%
#fancy restaurants map
fancy_down = fancy_downtown[["latitude", "longitude"]]
fancy_marks = fancy_downtown_mark[["latitude", "longitude"]]
fig = gmaps.figure()
fancy_symbols = gmaps.symbol_layer(fancy_down, fill_color="blue", stroke_color = "blue")
fig.add_layer(fancy_symbols)
fancy_marks_1 = gmaps.marker_layer(fancy_marks)
fig.add_layer(fancy_marks_1)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#lets get something cheap but I promise it is clean
cheap_downtown = zip_downtown.loc[zip_downtown["price_integer"] == 1]
cheap_downtown = cheap_downtown.loc[cheap_downtown["rating"]>3]
cheap_downtown["AKA Name"].value_counts()
# Out:
# JIMMY JOHN'S              14
# PROTEIN BAR                9
# MIXED GREENS               5
# MARKET CREATIONS           5
# MCDONALD'S                 5
# CHIPOTLE MEXICAN GRILL     4
# STAN'S DONUTS & COFFEE     4
# FRESHII                    3
# NAF NAF GRILL              3
# ROTI                       3
# WHICH WICH                 2
# FABCAKES                   2
# CAFECITO                   2
# McDonald's                 2
# WOW BAO                    2
# MORGAN STREET CAFE         2
# M2 Cafe                    2
# POCKETS                    2
# ARTURO EXPRESS             2
# BENJYEHUDA                 2
# THAI BOWL                  2
# CHINA NIGHT CAFE           2
# EAT ME MILK ME             2
# JASON'S DELI               2
# BOAR'S HEAD CAFE           1
# PORTILLO'S HOT DOGS        1
# CONTE DI SAVOIA            1
# OASIS CAFE                 1
# BOXCAR BETTY'S             1
# 65 EXPRESS                 1
# PAPPAROTI                  1
# Just Salad                 1
# YUMMY THAI                 1
# LOTUS BANH MI              1
# NEW ORLEANS KITCHEN        1
# GOLDEN THAI                1
# BURRITO BEACH              1
# SEOUL TACO                 1
# GREEN APPLE PHOEVER        1
# Name: AKA Name, dtype: int64

# %%
#create markers for 3 restaurant names
place = ["100 W ONTARIO ST ", "33 N DEARBORN ST ", "200 W ADAMS ST "]
cheap_downtown_mark = cheap_downtown.loc[cheap_downtown["Address"].isin(place),:]
cheap_downtown_mark
# Out:
#       Unnamed: 0             AKA Name Facility Type           Risk  \
# 1012        1012                 ROTI    Restaurant  Risk 1 (High)
# 2772        2772        LOTUS BANH MI    Restaurant  Risk 1 (High)
# 4734        4734  PORTILLO'S HOT DOGS    Restaurant  Risk 1 (High)
#
#                 Address      Zip  Year          Inspection Type Results  \
# 1012  33 N DEARBORN ST   60602.0  2021                  Canvass    Pass
# 2772    200 W ADAMS ST   60606.0  2021                  Canvass    Pass
# 4734  100 W ONTARIO ST   60654.0  2020  Complaint Re-Inspection    Pass
#
#                                              Violations  ...  \
# 1012  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  ...
# 2772  29. COMPLIANCE WITH VARIANCE/SPECIALIZED PROCE...  ...
# 4734                                                NaN  ...
#
#                                    display_address             address1  \
# 1012    ['200 W Randolph St', 'Chicago, IL 60601']    200 W Randolph St
# 2772  ['166 W Washington St', 'Chicago, IL 60602']  166 W Washington St
# 4734        ['100 W Ontario', 'Chicago, IL 60654']        100 W Ontario
#
#       address2  address3     city   latitude  longitude zip code  \
# 1012       NaN       NaN  Chicago  41.884893 -87.634141    60601
# 2772       NaN       NaN  Chicago  41.883460 -87.633050    60602
# 4734       NaN       NaN  Chicago  41.893660 -87.631570    60654
#
#                restaurant_id  price_integer
# 1012  1rJZHq8Cce3PJxCte1lalw            1.0
# 2772  Kv9UwSyIsdEPBuUIXs8YpA            1.0
# 4734  rp17Dfjdh7JR4GGZwj6nqg            1.0
#
# [3 rows x 32 columns]

# %%
#creat a map for cheap, clean, places highly rated!
cheap_down = cheap_downtown[["latitude", "longitude"]]
cheap_marks = cheap_downtown_mark[["latitude", "longitude"]]
fig = gmaps.figure()
cheap_symbols = gmaps.symbol_layer(cheap_down, fill_color="blue", stroke_color = "blue")
fig.add_layer(cheap_symbols)
cheap_marks_1 = gmaps.marker_layer(cheap_marks)
fig.add_layer(cheap_marks_1)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
