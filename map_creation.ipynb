# %%
#Import the necessary functions
from pprint import pprint
import pandas as pd 
import requests
import numpy as np
import gmaps

from config import yelp_key
from config import g_key

# %%
#import the csv file
data = pd.read_csv("CSV_Output/eg_merge_testing.csv")
data
# Out:
#      Unnamed: 0              Address           Address_old  \
# 0             0    4412 N Pulaski Rd    4412 N Pulaski Rd
# 1             1    4412 N Pulaski Rd    4412 N Pulaski Rd
# 2             2    1116 W Madison St    1116 W Madison St
# 3             3    1116 W Madison St    1116 W Madison St
# 4             4       2132 W Chicago      2132 W Chicago
# ..          ...                  ...                   ...
# 620         620     5422 W Fullerton    5422 W Fullerton
# 621         621       222 W Adams St       222 W Adams St
# 622         622       116 S Michigan      116 S Michigan
# 623         623  5630 W Roosevelt Rd  5630 W Roosevelt Rd
# 624         624       3333 W Belmont      3333 W Belmont
#
#                    AKA Name Facility Type             Risk      Zip  Year  \
# 0                   WENDY'S    Restaurant    Risk 1 (High)  60630.0  2022
# 1                   WENDY'S    Restaurant    Risk 1 (High)  60630.0  2022
# 2           VietFive Coffee    Restaurant  Risk 2 (Medium)  60607.0  2022
# 3           VietFive Coffee    Restaurant  Risk 2 (Medium)  60607.0  2022
# 4               TAKIE OUTIT    Restaurant    Risk 1 (High)  60622.0  2022
# ..                      ...           ...              ...      ...   ...
# 620            SAZON CUBANO    Restaurant    Risk 1 (High)  60639.0  2022
# 621  SOPRAFFINA MARKETCAFFE    Restaurant    Risk 1 (High)  60606.0  2022
# 622                JOLLIBEE    Restaurant    Risk 1 (High)  60603.0  2022
# 623                  SUBWAY    Restaurant    Risk 1 (High)  60644.0  2022
# 624                  SUBWAY    Restaurant    Risk 1 (High)  60618.0  2022
#
#              Inspection Type Results  ...  \
# 0    Complaint Re-Inspection    Pass  ...
# 1       Short Form Complaint    Fail  ...
# 2      License Re-Inspection    Pass  ...
# 3                    License    Fail  ...
# 4      License Re-Inspection    Pass  ...
# ..                       ...     ...  ...
# 620                  Canvass    Pass  ...
# 621                  Canvass    Pass  ...
# 622                Complaint    Fail  ...
# 623                  Canvass    Pass  ...
# 624                  Canvass    Pass  ...
#
#                                        display_address              address1  \
# 0           ['4412 N Pulaski Rd', 'Chicago, IL 60630']     4412 N Pulaski Rd
# 1           ['4412 N Pulaski Rd', 'Chicago, IL 60630']     4412 N Pulaski Rd
# 2           ['1116 W Madison St', 'Chicago, IL 60607']     1116 W Madison St
# 3           ['1116 W Madison St', 'Chicago, IL 60607']     1116 W Madison St
# 4          ['2132 W Chicago Ave', 'Chicago, IL 60622']    2132 W Chicago Ave
# ..                                                 ...                   ...
# 620      ['5422 W Fullerton Ave', 'Chicago, IL 60639']  5422 W Fullerton Ave
# 621        ['175 W Jackson Blvd', 'Chicago, IL 60604']    175 W Jackson Blvd
# 622        ['116 S Michigan Ave', 'Chicago, IL 60603']    116 S Michigan Ave
# 623       ['5630 W Roosevelt Rd', 'Chicago, IL 60644']   5630 W Roosevelt Rd
# 624  ['3333 W Belmont Ave', 'Space 101', 'Chicago, ...    3333 W Belmont Ave
#
#       address2  address3     city   latitude  longitude zip code  \
# 0          NaN       NaN  Chicago  41.961428 -87.728149    60630
# 1          NaN       NaN  Chicago  41.961428 -87.728149    60630
# 2          NaN       NaN  Chicago  41.881840 -87.655100    60607
# 3          NaN       NaN  Chicago  41.881840 -87.655100    60607
# 4          NaN       NaN  Chicago  41.896110 -87.680860    60622
# ..         ...       ...      ...        ...        ...      ...
# 620        NaN       NaN  Chicago  41.924210 -87.762080    60639
# 621        NaN       NaN  Chicago  41.877490 -87.633189    60604
# 622        NaN       NaN  Chicago  41.880220 -87.624970    60603
# 623        NaN       NaN  Chicago  41.865720 -87.765713    60644
# 624  Space 101       NaN  Chicago  41.939004 -87.711434    60618
#
#               restaurant_id price_integer
# 0    NztYcb9i_D9E563x1XVUsQ           1.0
# 1    NztYcb9i_D9E563x1XVUsQ           1.0
# 2    zrgjSslmZzgmF6H4ZU3HxA           NaN
# 3    zrgjSslmZzgmF6H4ZU3HxA           NaN
# 4    rd4NrLcEOKBVaGRIkC35NQ           1.0
# ..                      ...           ...
# 620  1e4EwmIROSP9brcpLc8tew           NaN
# 621  PKn611tgOKdzSH_y0bHfjA           2.0
# 622  uZzSkUNrEFUwpMP7F50yCA           NaN
# 623  EfP955wxtzl8Uqdh-Z9dCA           1.0
# 624  DzgVXaINxH3OMfrT-xzgCA           1.0
#
# [625 rows x 33 columns]

# %%
#create a dataframe with a great rating
great_df = data.loc[data["rating"]>=4]
good_df = data.loc[data["rating"]< 4]
good_df = good_df.loc[good_df["rating"]>=2]
bad_df = data.loc[data["rating"] <2]

# %%
#create a map with the great dataframe
great_health = great_df.loc[great_df["Results"] == "Pass"]
bad_health = great_df.loc[great_df["Results"] =="Fail"]
vbad_health = bad_df.loc[bad_df["Results"]=="Fail"]
notbad_health = bad_df.loc[bad_df["Results"] == "Pass"]

#configure the gmaps
gmaps.configure(api_key=g_key)

# %%
green_locations = great_health[["Latitude", "Longitude"]]
yellow_locations = bad_health[["Latitude", "Longitude"]]
red_locations = vbad_health[["Latitude", "Longitude"]]
blue_locations = notbad_health[["Latitude", "Longitude"]]
# names = list(great_health["name"])                            
fig = gmaps.figure()
# marker = gmaps.marker_layer(green_locations)

# fig.add_layer(marker)
#change the color of the marker
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)

# new_markers = gmaps.marker_layer(orange_locations)

# fig.add_layer(new_markers)

yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color = "yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)

red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color="red")
fig.add_layer(red_symbols)

blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color="blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create maps individually for each type
green_locations = great_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
yellow_locations = bad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color="yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
red_locations = vbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color = "red")
fig.add_layer(red_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
blue_locations = notbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#potential maps I could make
#comparing the more popular zip codes and see which one has the most highest rated restaurants
great_health["Zip"].value_counts()
zip_code_60661 = great_health.loc[great_health["Zip"] == 60661]
data_60661 = data.loc[data["Zip"] == 60661]
zip_code_60661
# Out:
#      Unnamed: 0               Address            Address_old  \
# 176         176          14 S Clinton          14 S Clinton
# 177         177          14 S Clinton          14 S Clinton
# 315         315        625 W Adams St        625 W Adams St
# 316         316        625 W Adams St        625 W Adams St
# 378         378      131 N Clinton St      131 N Clinton St
# 497         497  301-305 S Halsted St  301-305 S Halsted St
#
#                   AKA Name Facility Type           Risk      Zip  Year  \
# 176          NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 177          NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 315       MARKET CREATIONS    Restaurant  Risk 1 (High)  60661.0  2022
# 316       MARKET CREATIONS    Restaurant  Risk 1 (High)  60661.0  2022
# 378      THE HAPPY LOBSTER    Restaurant  Risk 1 (High)  60661.0  2022
# 497  MELI CAFE & JUICE BAR    Restaurant  Risk 1 (High)  60661.0  2022
#
#            Inspection Type Results  ...  \
# 176  Canvass Re-Inspection    Pass  ...
# 177  Canvass Re-Inspection    Pass  ...
# 315                License    Pass  ...
# 316                License    Pass  ...
# 378  Canvass Re-Inspection    Pass  ...
# 497  Canvass Re-Inspection    Pass  ...
#
#                                        display_address             address1  \
# 176       ['309 W Washington St', 'Chicago, IL 60606']  309 W Washington St
# 177           ['14 S Clinton St', 'Chicago, IL 60661']      14 S Clinton St
# 315  ['233 S Wacker Dr', 'Fl 2', 'Willis Tower', 'C...      233 S Wacker Dr
# 316   ['1 S Franklin St', 'Fl 2', 'Chicago, IL 60606']      1 S Franklin St
# 378          ['131 N Clinton St', 'Chicago, IL 60661']     131 N Clinton St
# 497          ['301 S Halsted St', 'Chicago, IL 60661']     301 S Halsted St
#
#      address2      address3     city   latitude  longitude zip code  \
# 176       NaN           NaN  Chicago  41.883107 -87.635624    60606
# 177       NaN           NaN  Chicago  41.881335 -87.641368    60661
# 315      Fl 2  Willis Tower  Chicago  41.878820 -87.635956    60606
# 316      Fl 2           NaN  Chicago  41.881546 -87.635054    60606
# 378       NaN           NaN  Chicago  41.884282 -87.641097    60661
# 497       NaN           NaN  Chicago  41.877610 -87.647000    60661
#
#               restaurant_id price_integer
# 176  8BXbNpuPz_WR92_LE8V8kQ           1.0
# 177  w6-s9rcX1aocHS0t68odjw           1.0
# 315  IS8V9ivSWrmTm8wU-QS0Jg           1.0
# 316  Em3GSPR2REgo6HFEmFkepQ           NaN
# 378  figkYyQO-6kmS3gw8K34kA           2.0
# 497  tCkwBTuEFvhuaBoEUWqbuQ           2.0
#
# [6 rows x 33 columns]

# %%
data_60661
# Out:
#      Unnamed: 0               Address            Address_old  \
# 165         165       525 W Monroe St       525 W Monroe St
# 166         166       525 W Monroe St       525 W Monroe St
# 176         176          14 S Clinton          14 S Clinton
# 177         177          14 S Clinton          14 S Clinton
# 178         178          14 S Clinton          14 S Clinton
# 179         179          14 S Clinton          14 S Clinton
# 203         203      500 W Madison St      500 W Madison St
# 314         314        625 W Adams St        625 W Adams St
# 315         315        625 W Adams St        625 W Adams St
# 316         316        625 W Adams St        625 W Adams St
# 378         378      131 N Clinton St      131 N Clinton St
# 379         379      131 N Clinton St      131 N Clinton St
# 409         409      500 W Madison St      500 W Madison St
# 410         410      500 W Madison St      500 W Madison St
# 421         421    304 S Jefferson St    304 S Jefferson St
# 496         496  301-305 S Halsted St  301-305 S Halsted St
# 497         497  301-305 S Halsted St  301-305 S Halsted St
# 508         508      500 W Madison St      500 W Madison St
#
#                    AKA Name Facility Type           Risk      Zip  Year  \
# 165  CHIPOTLE MEXICAN GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 166  CHIPOTLE MEXICAN GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 176           NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 177           NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 178           NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 179           NAF NAF GRILL    Restaurant  Risk 1 (High)  60661.0  2022
# 203           BURRITO BEACH    Restaurant  Risk 1 (High)  60661.0  2022
# 314        MARKET CREATIONS    Restaurant  Risk 1 (High)  60661.0  2022
# 315        MARKET CREATIONS    Restaurant  Risk 1 (High)  60661.0  2022
# 316        MARKET CREATIONS    Restaurant  Risk 1 (High)  60661.0  2022
# 378       THE HAPPY LOBSTER    Restaurant  Risk 1 (High)  60661.0  2022
# 379       THE HAPPY LOBSTER    Restaurant  Risk 1 (High)  60661.0  2022
# 409      CORNER BAKERY CAFE    Restaurant  Risk 1 (High)  60661.0  2022
# 410      CORNER BAKERY CAFE    Restaurant  Risk 1 (High)  60661.0  2022
# 421                  SUBWAY    Restaurant  Risk 1 (High)  60661.0  2022
# 496   MELI CAFE & JUICE BAR    Restaurant  Risk 1 (High)  60661.0  2022
# 497   MELI CAFE & JUICE BAR    Restaurant  Risk 1 (High)  60661.0  2022
# 508              BENJYEHUDA    Restaurant  Risk 1 (High)  60661.0  2022
#
#            Inspection Type Results  ...  \
# 165                Canvass    Pass  ...
# 166                Canvass    Pass  ...
# 176  Canvass Re-Inspection    Pass  ...
# 177  Canvass Re-Inspection    Pass  ...
# 178                Canvass    Fail  ...
# 179                Canvass    Fail  ...
# 203                Canvass    Pass  ...
# 314                License    Pass  ...
# 315                License    Pass  ...
# 316                License    Pass  ...
# 378  Canvass Re-Inspection    Pass  ...
# 379                Canvass    Fail  ...
# 409  Canvass Re-Inspection    Pass  ...
# 410                Canvass    Fail  ...
# 421  Canvass Re-Inspection    Pass  ...
# 496  Canvass Re-Inspection    Fail  ...
# 497  Canvass Re-Inspection    Pass  ...
# 508                Canvass    Pass  ...
#
#                                        display_address             address1  \
# 165  ['525 W Monroe St', 'Ste L1A', 'Chicago, IL 60...      525 W Monroe St
# 166  ['311 S Wacker Dr', 'Lowr 100', 'Chicago, IL 6...      311 S Wacker Dr
# 176       ['309 W Washington St', 'Chicago, IL 60606']  309 W Washington St
# 177           ['14 S Clinton St', 'Chicago, IL 60661']      14 S Clinton St
# 178       ['309 W Washington St', 'Chicago, IL 60606']  309 W Washington St
# 179           ['14 S Clinton St', 'Chicago, IL 60661']      14 S Clinton St
# 203          ['500 W Madison St', 'Chicago, IL 60661']     500 W Madison St
# 314   ['101 N Wacker', 'Ste 103', 'Chicago, IL 60606']         101 N Wacker
# 315  ['233 S Wacker Dr', 'Fl 2', 'Willis Tower', 'C...      233 S Wacker Dr
# 316   ['1 S Franklin St', 'Fl 2', 'Chicago, IL 60606']      1 S Franklin St
# 378          ['131 N Clinton St', 'Chicago, IL 60661']     131 N Clinton St
# 379          ['131 N Clinton St', 'Chicago, IL 60661']     131 N Clinton St
# 409       ['222 S Riverside Plz', 'Chicago, IL 60606']  222 S Riverside Plz
# 410       ['222 S Riverside Plz', 'Chicago, IL 60606']  222 S Riverside Plz
# 421  ['304 S Jefferson St', 'Ste A', 'Chicago, IL 6...   304 S Jefferson St
# 496          ['301 S Halsted St', 'Chicago, IL 60661']     301 S Halsted St
# 497          ['301 S Halsted St', 'Chicago, IL 60661']     301 S Halsted St
# 508             ['500 W Madison', 'Chicago, IL 60661']        500 W Madison
#
#      address2      address3     city   latitude  longitude zip code  \
# 165   Ste L1A           NaN  Chicago  41.880371 -87.640869    60661
# 166  Lowr 100           NaN  Chicago  41.877676 -87.635353    60606
# 176       NaN           NaN  Chicago  41.883107 -87.635624    60606
# 177       NaN           NaN  Chicago  41.881335 -87.641368    60661
# 178       NaN           NaN  Chicago  41.883107 -87.635624    60606
# 179       NaN           NaN  Chicago  41.881335 -87.641368    60661
# 203       NaN           NaN  Chicago  41.882674 -87.640578    60661
# 314   Ste 103           NaN  Chicago  41.883530 -87.636540    60606
# 315      Fl 2  Willis Tower  Chicago  41.878820 -87.635956    60606
# 316      Fl 2           NaN  Chicago  41.881546 -87.635054    60606
# 378       NaN           NaN  Chicago  41.884282 -87.641097    60661
# 379       NaN           NaN  Chicago  41.884282 -87.641097    60661
# 409       NaN           NaN  Chicago  41.878514 -87.639324    60606
# 410       NaN           NaN  Chicago  41.878514 -87.639324    60606
# 421     Ste A           NaN  Chicago  41.877508 -87.642261    60661
# 496       NaN           NaN  Chicago  41.877610 -87.647000    60661
# 497       NaN           NaN  Chicago  41.877610 -87.647000    60661
# 508       NaN           NaN  Chicago  41.882578 -87.640256    60661
#
#               restaurant_id price_integer
# 165  _0D1RwA54zkIhQhlPMGIag           1.0
# 166  T2avHWWd2lgZV9F0V8B-KA           1.0
# 176  8BXbNpuPz_WR92_LE8V8kQ           1.0
# 177  w6-s9rcX1aocHS0t68odjw           1.0
# 178  8BXbNpuPz_WR92_LE8V8kQ           1.0
# 179  w6-s9rcX1aocHS0t68odjw           1.0
# 203  npDyi-K7jhH6hH2RZ6XZxA           1.0
# 314  4Q2n-tIrgcmzgFkRr99G8Q           NaN
# 315  IS8V9ivSWrmTm8wU-QS0Jg           1.0
# 316  Em3GSPR2REgo6HFEmFkepQ           NaN
# 378  figkYyQO-6kmS3gw8K34kA           2.0
# 379  figkYyQO-6kmS3gw8K34kA           2.0
# 409  N_t2JG-ppf6qILzTZKfYDw           2.0
# 410  N_t2JG-ppf6qILzTZKfYDw           2.0
# 421  SoXjfbiVk6JEaCc6lZgWNw           NaN
# 496  tCkwBTuEFvhuaBoEUWqbuQ           2.0
# 497  tCkwBTuEFvhuaBoEUWqbuQ           2.0
# 508  z5nkKjat1z4qinPVUFZ3fA           1.0
#
# [18 rows x 33 columns]

# %%
zip60661_locations = data_60661[["Latitude", "Longitude"]]
fig = gmaps.figure()
zip60661_symbols = gmaps.symbol_layer(zip60661_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(zip60661_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a map of the great rating restaurants in 60661
great_data_60661 = data_60661.loc[data_60661["rating"] > 4]
great60661_locations = great_data_60661[["Latitude", "Longitude"]]
fig = gmaps.figure()
great60661_symbols = gmaps.symbol_layer(great60661_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60661_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
data_60657 = data.loc[data["zip code_y"] == 60657]
data_60613 = data.loc[data["zip code_y"] == 60613]
great_data_60657 = data_60657[data_60657["rating"]>=4]
great_data_60613 = data_60613[data_60613["rating"]>=4]
data_60657
# Out:
#      Unnamed: 0                                     name      category  \
# 16         6147                               Little Wok       chinese
# 18         2046                               Waterhouse   newamerican
# 20         2088                           Christmas Club          bars
# 99         6151                           Zazas Pizzeria         pizza
# 221        6584                       Nola Bar & Kitchen  cocktailbars
# 271        6147                               Little Wok       chinese
# 448         139  St. Joseph's Hospital - Lake Shore Cafe         cafes
# 689        6744                                  Banh Mi    vietnamese
# 738        6151                           Zazas Pizzeria         pizza
# 862        6064                      Lowcountry Lakeview         cajun
# 918        6744                                  Banh Mi    vietnamese
#
#      category_title  rating price  review_count  \
# 16          Chinese     4.0    $$           274
# 18   American (New)     3.5    $$           352
# 20             Bars     3.0    $$            20
# 99            Pizza     5.0   NaN            64
# 221   Cocktail Bars     4.0    $$           128
# 271         Chinese     4.0    $$           274
# 448           Cafes     3.5     $             8
# 689      Vietnamese     4.0     $           330
# 738           Pizza     5.0   NaN            64
# 862    Cajun/Creole     4.5    $$           670
# 918      Vietnamese     4.0     $           330
#
#                                    display_address              address1  \
# 16        ['3144 N Broadway', 'Chicago, IL 60657']       3144 N Broadway
# 18      ['3407 N Paulina St', 'Chicago, IL 60657']     3407 N Paulina St
# 20        ['3462 N Clark St', 'Chicago, IL 60657']       3462 N Clark St
# 99        ['3037 N Clark St', 'Chicago, IL 60657']       3037 N Clark St
# 221       ['3481 N Clark St', 'Chicago, IL 60657']       3481 N Clark St
# 271       ['3144 N Broadway', 'Chicago, IL 60657']       3144 N Broadway
# 448  ['2900 N Lake Shore Dr', 'Chicago, IL 60657']  2900 N Lake Shore Dr
# 689       ['3227 N Clark St', 'Chicago, IL 60657']       3227 N Clark St
# 738       ['3037 N Clark St', 'Chicago, IL 60657']       3037 N Clark St
# 862       ['3343 N Clark St', 'Chicago, IL 60657']       3343 N Clark St
# 918       ['3227 N Clark St', 'Chicago, IL 60657']       3227 N Clark St
#
#     address2  ...                     AKA Name Facility Type           Risk  \
# 16       NaN  ...                   LITTLE WOK    Restaurant  Risk 1 (High)
# 18       NaN  ...  WATERHOUSE TAVERN AND GRILL    Restaurant  Risk 1 (High)
# 20       NaN  ...                 COUNTRY CLUB    Restaurant  Risk 1 (High)
# 99       NaN  ...           ZAZAS PIZZERIA LLC    Restaurant  Risk 1 (High)
# 221      NaN  ...              NOLA CAFE & BAR    Restaurant  Risk 1 (High)
# 271      NaN  ...                   LITTLE WOK    Restaurant  Risk 1 (High)
# 448      NaN  ...          ST. JOSEPH HOSPITAL    Restaurant  Risk 1 (High)
# 689      NaN  ...                BANH MI & CO.    Restaurant  Risk 1 (High)
# 738      NaN  ...           ZAZAS PIZZERIA LLC    Restaurant  Risk 1 (High)
# 862      NaN  ...                   LOWCOUNTRY    Restaurant  Risk 1 (High)
# 918      NaN  ...                BANH MI & CO.    Restaurant  Risk 1 (High)
#
#      zip code_y  Year          Inspection Type  Results  \
# 16        60657  2022                Complaint     Fail
# 18        60657  2022                  Canvass     Pass
# 20        60657  2022                  Canvass     Pass
# 99        60657  2022    Canvass Re-Inspection     Pass
# 221       60657  2022                  Canvass     Pass
# 271       60657  2022  Complaint Re-Inspection     Pass
# 448       60657  2022                  Canvass     Fail
# 689       60657  2022                  License     Fail
# 738       60657  2022                  Canvass     Fail
# 862       60657  2022                  Canvass     Pass
# 918       60657  2022    License Re-Inspection     Pass
#
#                                             Violations   Latitude  Longitude
# 16   3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.939052 -87.644513
# 18   43. IN-USE UTENSILS: PROPERLY STORED - Comment...  41.943573 -87.671059
# 20   43. IN-USE UTENSILS: PROPERLY STORED - Comment...  41.945050 -87.654953
# 99                                                 NaN  41.937433 -87.648465
# 221  35. APPROVED THAWING METHODS USED - Comments: ...  41.945603 -87.655057
# 271                                                NaN  41.939052 -87.644513
# 448  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.934403 -87.636806
# 689  16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  41.940730 -87.651134
# 738  5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.937433 -87.648465
# 862  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  41.942869 -87.652863
# 918                                                NaN  41.940730 -87.651134
#
# [11 rows x 28 columns]

# %%
#create a graph showing whether you should go north or south for a good restaurant before/after a cubs game
great60657_locations = great_data_60657[["Latitude", "Longitude"]]
great60613_locations = great_data_60613[["Latitude", "Longitude"]]
fig = gmaps.figure()
great60657_symbols = gmaps.symbol_layer(great60657_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(great60657_symbols)
great60613_symbols = gmaps.symbol_layer(great60613_locations, fill_color="red", stroke_color = "red")
fig.add_layer(great60613_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
just_ratings = pd.read_csv("CSV_Output/yelp_csv_Clean.csv")
just_ratings
# Out:
#       Unnamed: 0                        name       category  category_title  \
# 0              0             Tortas Frontera        mexican         Mexican
# 1              1             Farmer's Fridge          salad           Salad
# 2              2             Tortas Frontera        mexican         Mexican
# 3              3               Gaslight Club    newamerican  American (New)
# 4              4                    Big Bowl        chinese         Chinese
# ...          ...                         ...            ...             ...
# 6839        6839  The Dock At Montrose Beach    newamerican  American (New)
# 6840        6840     Wentworth Seafood House      bubbletea      Bubble Tea
# 6841        6841              Little Toasted    whiskeybars    Whiskey Bars
# 6842        6842          Dinner And A Movie  movietheaters          Cinema
# 6843        6843         Taqueria Traspasada        mexican         Mexican
#
#       rating price  review_count  \
# 0        4.0    $$          1395
# 1        4.5     $            62
# 2        4.0    $$          1321
# 3        3.5   $$$            99
# 4        2.0    $$            36
# ...      ...   ...           ...
# 6839     3.0    $$           316
# 6840     4.0    $$           125
# 6841     4.0    $$            70
# 6842     2.5    $$            17
# 6843     4.0     $           401
#
#                                         display_address  \
# 0     ['Terminal 3 - Gate K4', "10000 W O'Hare Ave",...
# 1     ['10000 Ohare Way', 'Terminal 3 Gate K6', 'Chi...
# 2     ["10000 W O'Hare Ave", 'Terminal 1 - Gate B11'...
# 3     ["Chicago O'Hare International Airport", "O'Ha...
# 4     ["10000 West O'hare Ave", 'Terminal 5; Gate M7...
# ...                                                 ...
# 6839  ['200 W Montrose Harbor Dr', 'Chicago, IL 60601']
# 6840      ['2229 S Wentworth Ave', 'Chicago, IL 60616']
# 6841           ['300 S Riverside', 'Chicago, IL 60606']
# 6842        ['2500 N Ashland Ave', 'Chicago, IL 60614']
# 6843         ['811 N Ashland Ave', 'Chicago, IL 60622']
#
#                                   address1            address2  \
# 0                     Terminal 3 - Gate K4  10000 W O'Hare Ave
# 1                          10000 Ohare Way                 NaN
# 2                       10000 W O'Hare Ave                 NaN
# 3     Chicago O'Hare International Airport                 NaN
# 4                    10000 West O'hare Ave                 NaN
# ...                                    ...                 ...
# 6839              200 W Montrose Harbor Dr                 NaN
# 6840                  2229 S Wentworth Ave                 NaN
# 6841                       300 S Riverside                 NaN
# 6842                    2500 N Ashland Ave                 NaN
# 6843                     811 N Ashland Ave                 NaN
#
#                                address3     city   latitude  longitude  \
# 0        Terminal 3 Concourse K Gate K4  Chicago  41.975438 -87.900137
# 1                    Terminal 3 Gate K6  Chicago  41.975234 -87.898719
# 2                 Terminal 1 - Gate B11  Chicago  41.980026 -87.906679
# 3     O'Hare Hilton Hotel - Lobby Level  Chicago  41.977965 -87.905173
# 4                   Terminal 5; Gate M7  Chicago  41.975103 -87.891350
# ...                                 ...      ...        ...        ...
# 6839                                NaN  Chicago  41.964596 -87.636395
# 6840                                NaN  Chicago  41.852301 -87.631849
# 6841                                NaN  Chicago  41.877410 -87.638760
# 6842                                NaN  Chicago  41.927070 -87.668560
# 6843                                NaN  Chicago  41.896330 -87.667050
#
#       zip code           restaurant_id  price_integer
# 0        60666  1zZvM7Zy__Oh533E4bt6_A            2.0
# 1        60666  4xQv1b1IFRsAWZu7yVLFrQ            1.0
# 2        60666  0k018u1PAtfmkNRYk04yCQ            2.0
# 3        60666  MywzBEKWjmt0bcNajKt8yw            3.0
# 4        60666  6VZwwWxBmxMsKd10AIOjxg            2.0
# ...        ...                     ...            ...
# 6839     60601  lf8WcC4IvzvmvlSmYIoi3Q            2.0
# 6840     60616  rVRMpovx68BZXTLedFwB5Q            2.0
# 6841     60606  IfQOHedYrGg9m9lXWE5NWw            2.0
# 6842     60614  v02hTCN65wPueVeZZniYPw            2.0
# 6843     60622  nTL9tlTqGr5-J68W-3Szww            1.0
#
# [6844 rows x 17 columns]

# %%
just_ratings_60657 = just_ratings.loc[just_ratings["rating"]>=3]
just_ratings_60613 = just_ratings.loc[just_ratings["rating"]>=3]
ratings_60657 = just_ratings_60657.loc[just_ratings_60657["zip code"] == 60657]
ratings_60613 = just_ratings_60613.loc[just_ratings_60613["zip code"] == 60613]

# %%
_60657_locations = ratings_60657[["latitude", "longitude"]]
_60613_locations = ratings_60613[["latitude", "longitude"]]
fig = gmaps.figure()
_60657_symbols = gmaps.symbol_layer(_60657_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(_60657_symbols)
_60613_symbols = gmaps.symbol_layer(_60613_locations, fill_color="red", stroke_color = "red")
fig.add_layer(_60613_symbols)
fig
# add review counts of over 100
#add different colors for different types of food
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a dataframe of 60657 and 60613 with 2-3 rating and a pass
beer_data = data.loc[data["rating"] >= 2]
beer_data = beer_data.loc[beer_data["rating"] <= 3]
beer_data
# Out:
#      Unnamed: 0               Address            Address_old  \
# 7             7        6216 W 63Rd St        6216 W 63Rd St
# 8             8        6216 W 63Rd St        6216 W 63Rd St
# 13           13        1300 N Ashland       1300 N Ashland
# 19           19           900 W North          900 W North
# 20           20           900 W North          900 W North
# ..          ...                   ...                    ...
# 608         608     203 N La Salle St     203 N La Salle St
# 611         611             6 W Grand            6 W Grand
# 613         613      4861 N Milwaukee     4861 N Milwaukee
# 619         619  3550-3554 N Clark St  3550-3554 N Clark St
# 624         624        3333 W Belmont       3333 W Belmont
#
#                         AKA Name Facility Type           Risk      Zip  Year  \
# 7                63RD FRIED RICE    Restaurant  Risk 1 (High)  60638.0  2022
# 8                63RD FRIED RICE    Restaurant  Risk 1 (High)  60638.0  2022
# 13                        SUBWAY    Restaurant  Risk 1 (High)  60622.0  2022
# 19        POTBELLY SANDWICH SHOP    Restaurant  Risk 1 (High)  60642.0  2022
# 20        POTBELLY SANDWICH SHOP    Restaurant  Risk 1 (High)  60642.0  2022
# ..                           ...           ...            ...      ...   ...
# 608  HALSTED STREET DELI & BAGEL    Restaurant  Risk 1 (High)  60601.0  2022
# 611       Chipotle Mexican Grill    Restaurant  Risk 1 (High)  60654.0  2022
# 613                       SUBWAY    Restaurant  Risk 1 (High)  60630.0  2022
# 619               VINES ON CLARK    Restaurant  Risk 1 (High)  60657.0  2022
# 624                       SUBWAY    Restaurant  Risk 1 (High)  60618.0  2022
#
#            Inspection Type Results  ...  \
# 7    License Re-Inspection    Pass  ...
# 8                  License    Fail  ...
# 13                 Canvass    Pass  ...
# 19   Canvass Re-Inspection    Pass  ...
# 20                 Canvass    Fail  ...
# ..                     ...     ...  ...
# 608                Canvass    Pass  ...
# 611                Canvass    Pass  ...
# 613                Canvass    Pass  ...
# 619                Canvass    Pass  ...
# 624                Canvass    Pass  ...
#
#                                        display_address  \
# 7              ['6216 W 63rd St', 'Chicago, IL 60638']
# 8              ['6216 W 63rd St', 'Chicago, IL 60638']
# 13   ['1300 N Ashland Ave', 'Ste P, Space 124', 'Ch...
# 19            ['900 W North Ave', 'Chicago, IL 60642']
# 20            ['900 W North Ave', 'Chicago, IL 60642']
# ..                                                 ...
# 608  ['222 W Merchandise Mart Plz', 'Chicago, IL 60...
# 611             ['6 W Grand Ave', 'Chicago, IL 60654']
# 613      ['4861 N Milwaukee Ave', 'Chicago, IL 60630']
# 619           ['3554 N Clark St', 'Chicago, IL 60657']
# 624  ['3333 W Belmont Ave', 'Space 101', 'Chicago, ...
#
#                        address1          address2  address3     city  \
# 7                6216 W 63rd St               NaN       NaN  Chicago
# 8                6216 W 63rd St               NaN       NaN  Chicago
# 13           1300 N Ashland Ave  Ste P, Space 124       NaN  Chicago
# 19              900 W North Ave               NaN       NaN  Chicago
# 20              900 W North Ave               NaN       NaN  Chicago
# ..                          ...               ...       ...      ...
# 608  222 W Merchandise Mart Plz               NaN       NaN  Chicago
# 611               6 W Grand Ave               NaN       NaN  Chicago
# 613        4861 N Milwaukee Ave               NaN       NaN  Chicago
# 619             3554 N Clark St               NaN       NaN  Chicago
# 624          3333 W Belmont Ave         Space 101       NaN  Chicago
#
#       latitude  longitude zip code           restaurant_id price_integer
# 7    41.777917 -87.777157    60638  mGMjCN-pK7yvKVaZdD9hLw           NaN
# 8    41.777917 -87.777157    60638  mGMjCN-pK7yvKVaZdD9hLw           NaN
# 13   41.905505 -87.668887    60622  AFSmLmOaKqhzj9dQiB873g           1.0
# 19   41.911511 -87.650768    60642  ceXMp8FmR71DjCIPpS1-Vw           NaN
# 20   41.911511 -87.650768    60642  ceXMp8FmR71DjCIPpS1-Vw           NaN
# ..         ...        ...      ...                     ...           ...
# 608  41.888138 -87.634495    60654  gQHdyHsyqiDw_q8l9jEvwQ           1.0
# 611  41.891907 -87.628499    60654  dlimwTHlBMU9-woF5JwOew           1.0
# 613  41.968951 -87.761509    60630  s9blVnBPwCDPaPNOEHRVxA           1.0
# 619  41.946894 -87.656453    60657  tzvY0hGCrzH4CgEB7TDsgg           2.0
# 624  41.939004 -87.711434    60618  DzgVXaINxH3OMfrT-xzgCA           1.0
#
# [193 rows x 33 columns]

# %%
#create bar graph for each zip code for differnet variables (price/ratings/inspections)
