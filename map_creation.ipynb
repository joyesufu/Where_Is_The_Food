# %%
#Import the necessary functions
from pprint import pprint
import pandas as pd 
import requests
import numpy as np
import gmaps

from config import yelp_key
from config import g_key

# %%
#import the csv file
data = pd.read_csv("CSV_Output/Merged_Clean.csv")
data
# Out:
#      Unnamed: 0                         name     category  \
# 0          3560                      Wendy's      hotdogs
# 1          4779                   Giordano's        salad
# 2          5719       Potbelly Sandwich Shop   sandwiches
# 3          5502                    Amazon Go  convenience
# 4          5975  Wildberry Pancakes and Cafe     pancakes
# ..          ...                          ...          ...
# 960        4724                       Pi18en   newmexican
# 961        6277                       Pl-zen   gastropubs
# 962        3574                   McDonald's      hotdogs
# 963        4591  Fiesta Tamaleria Del Barrio      mexican
# 964        4774   Fiesta Tamaleria El Barrio      mexican
#
#           category_title  rating price  review_count  \
# 0              Fast Food     1.5     $            66
# 1                  Salad     2.5    $$            68
# 2             Sandwiches     3.0     $            30
# 3     Convenience Stores     3.5   NaN             4
# 4               Pancakes     4.5    $$          8246
# ..                   ...     ...   ...           ...
# 960  New Mexican Cuisine     3.5   NaN             3
# 961           Gastropubs     4.0    $$           389
# 962            Fast Food     2.5     $            30
# 963              Mexican     5.0   NaN             3
# 964              Mexican     4.5   NaN            12
#
#                                     display_address               address1  \
# 0        ['4412 N Pulaski Rd', 'Chicago, IL 60630']      4412 N Pulaski Rd
# 1           ['1401 W 18th St', 'Chicago, IL 60608']         1401 W 18th St
# 2          ['1 N La Salle St', 'Chicago, IL 60602']        1 N La Salle St
# 3        ['130 E Randolph St', 'Chicago, IL 60601']      130 E Randolph St
# 4        ['130 E Randolph St', 'Chicago, IL 60601']      130 E Randolph St
# ..                                              ...                    ...
# 960         ['1519 W 18th St', 'Chicago, IL 60608']         1519 W 18th St
# 961         ['1519 W 18th St', 'Chicago, IL 60608']         1519 W 18th St
# 962  ['3615 W Irving Park Rd', 'Chicago, IL 60618']  3615 W Irving Park Rd
# 963         ['1820 W 18th St', 'Chicago, IL 60608']         1820 W 18th St
# 964         ['1820 W 18th St', 'Chicago, IL 60608']         1820 W 18th St
#
#     address2  ...                     AKA Name Facility Type             Risk  \
# 0        NaN  ...                      WENDY'S    Restaurant    Risk 1 (High)
# 1        NaN  ...             GIORDANO'S PIZZA    Restaurant    Risk 1 (High)
# 2        NaN  ...  POTBELLY SANDWICH WORKS LLC    Restaurant    Risk 1 (High)
# 3        NaN  ...                   GIORDANO'S    Restaurant    Risk 1 (High)
# 4        NaN  ...                   GIORDANO'S    Restaurant    Risk 1 (High)
# ..       ...  ...                          ...           ...              ...
# 960      NaN  ...                       PI18EN    Restaurant    Risk 1 (High)
# 961      NaN  ...                       PI18EN    Restaurant    Risk 1 (High)
# 962      NaN  ...                    MCDONALDS    Restaurant  Risk 2 (Medium)
# 963      NaN  ...   FIESTA TAMALERIA EL BARRIO    Restaurant  Risk 2 (Medium)
# 964      NaN  ...   FIESTA TAMALERIA EL BARRIO    Restaurant  Risk 2 (Medium)
#
#      zip code_y  Year          Inspection Type  Results  \
# 0         60630  2022  Complaint Re-Inspection     Pass
# 1         60608  2022                  Canvass     Pass
# 2         60602  2022                  Canvass     Fail
# 3         60601  2022                  License     Pass
# 4         60601  2022                  License     Pass
# ..          ...   ...                      ...      ...
# 960       60608  2022                  Canvass     Fail
# 961       60608  2022                  Canvass     Fail
# 962       60618  2022                  Canvass     Pass
# 963       60608  2022                  License     Pass
# 964       60608  2022                  License     Pass
#
#                                             Violations   Latitude  Longitude
# 0                                                  NaN  41.961366 -87.727987
# 1    55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.857765 -87.661385
# 2    38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.881990 -87.632213
# 3    38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.884588 -87.623273
# 4    38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.884588 -87.623273
# ..                                                 ...        ...        ...
# 960  22. PROPER COLD HOLDING TEMPERATURES - Comment...  41.857714 -87.664542
# 961  22. PROPER COLD HOLDING TEMPERATURES - Comment...  41.857714 -87.664542
# 962  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.953647 -87.718485
# 963                                                NaN  41.857821 -87.671984
# 964                                                NaN  41.857821 -87.671984
#
# [965 rows x 28 columns]

# %%
#create a dataframe with a great rating
great_df = data.loc[data["rating"]>=4]
good_df = data.loc[data["rating"]< 4]
good_df = good_df.loc[good_df["rating"]>=2]
bad_df = data.loc[data["rating"] <2]

# %%
#create a map with the great dataframe
great_health = great_df.loc[great_df["Results"] == "Pass"]
bad_health = great_df.loc[great_df["Results"] =="Fail"]
vbad_health = bad_df.loc[bad_df["Results"]=="Fail"]
notbad_health = bad_df.loc[bad_df["Results"] == "Pass"]

#configure the gmaps
gmaps.configure(api_key=g_key)

# %%
green_locations = great_health[["Latitude", "Longitude"]]
yellow_locations = bad_health[["Latitude", "Longitude"]]
red_locations = vbad_health[["Latitude", "Longitude"]]
blue_locations = notbad_health[["Latitude", "Longitude"]]
# names = list(great_health["name"])                            
fig = gmaps.figure()
# marker = gmaps.marker_layer(green_locations)

# fig.add_layer(marker)
#change the color of the marker
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)

# new_markers = gmaps.marker_layer(orange_locations)

# fig.add_layer(new_markers)

yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color = "yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)

red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color="red")
fig.add_layer(red_symbols)

blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color="blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create maps individually for each type
green_locations = great_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
green_symbols = gmaps.symbol_layer(green_locations, fill_color="green", stroke_color = "green")
fig.add_layer(green_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
yellow_locations = bad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
yellow_symbols = gmaps.symbol_layer(yellow_locations, fill_color="yellow", stroke_color = "yellow")
fig.add_layer(yellow_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
red_locations = vbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
red_symbols = gmaps.symbol_layer(red_locations, fill_color="red", stroke_color = "red")
fig.add_layer(red_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
blue_locations = notbad_health[["Latitude", "Longitude"]]
fig = gmaps.figure()
blue_symbols = gmaps.symbol_layer(blue_locations, fill_color="blue", stroke_color = "blue")
fig.add_layer(blue_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#potential maps I could make
#comparing the more popular zip codes and see which one has the most highest rated restaurants
